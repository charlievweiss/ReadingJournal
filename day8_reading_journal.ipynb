# %% [markdown]
# # Day 8 Reading Journal
#
# This journal includes several required exercises, but it is meant to encourage active reading more generally.  You should use the journal to take detailed notes, catalog questions, and explore the content from Think Python deeply.
#
# Reading: Think Python Chapter 12
#
# **Due: Thursday, September 29 at 12 noon**

# %% [markdown]
# ## [Chapter 12](http://www.greenteapress.com/thinkpython/html/thinkpython013.html)

# %% [markdown]
# ### Exercise 2
# Exercise 12.2. In this example, ties are broken by comparing words, so words with the same length appear in reverse alphabetical order. For other applications you might want to break ties at ran- dom. Modify this example so that words with the same length appear in random order. Hint: see the random function in the random module.

# %%
from random import *

def sort_by_length(words):
    t = []
    for word in words:
       t.append((len(word)+random(), word))
    t.sort(reverse=True)
    res = []
    for length, word in t:
        res.append(word)
    return res

sort_by_length(["The", "wonderful", "thing", "about", "tiggers"])
# Out:
# ['wonderful', 'tiggers', 'thing', 'about', 'The']

# %% [markdown]
# ### Exercise 4
#
# 1. Write a program that reads a word list from a file (see Section 9.1) and prints all the sets of
# words that are anagrams.
# Here is an example of what the output might look like:
#
#      ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled']
#      ['retainers', 'ternaries']
#      ['generating', 'greatening']
#      ['resmelts', 'smelters', 'termless']
#
# Hint: you might want to build a dictionary that maps from a set of letters to a list of words that can be spelled with those letters. The question is, how can you represent the set of letters in a way that can be used as a key?

# %%
def print_anagrams(file_name):
    words = []
    # Reads word list from a file:
    fin = open(file_name)
    for line in fin:
        word = line.strip()
        words.append(word)
    # make dictionary
    words_dict = dict()
    for word in words:
        # make sorted word a key and add the word
        key = ''.join(sorted(word))
        if key in words_dict:
            words_dict[key].append(word)
        else:
            words_dict[key] = [word]
    for k in words_dict:
        if len(words_dict[k])>1:
            print words_dict[k]
    
print_anagrams('words.txt')
# Out:
# ['overprased', 'overspread']
# ['mures', 'muser', 'serum']
# ['clinkers', 'crinkles']
# ['heros', 'hoers', 'horse', 'shoer', 'shore']
# ['mongers', 'morgens']
# ['portends', 'protends']
# ['flatiron', 'inflator']
# ['blunging', 'bungling']
# ['instar', 'santir', 'strain', 'trains']
# ['invars', 'ravins']
# ['friaries', 'rarifies']
# ['don', 'nod']
# ['boatel', 'lobate', 'oblate']
# ['vowels', 'wolves']
# ['determines', 'misentered']
# ['pasturers', 'superstar']
# ['platanes', 'pleasant']
# ['culls', 'scull']
# ['glutting', 'guttling']
# ['bluest', 'bluets', 'bustle', 'sublet', 'subtle']
# ['discerned', 'rescinded']
# ['auctioning', 'cautioning']
# ['disburse', 'subsider']
# ['bard', 'brad', 'darb', 'drab']
# ['besotted', 'obtested']
# ['entasis', 'sestina', 'tansies', 'tisanes']
# ['savines', 'vinasse']
# ['other', 'throe']
# ['hippos', 'popish']
# ['denary', 'yarned']
# ['ardent', 'ranted']
# ['darner', 'errand']
# ['actorish', 'chariots', 'haricots']
# ['rented', 'tender']
# ['endure', 'enured']
# ['denser', 'enders', 'resend', 'sender']
# ['earthing', 'hearting', 'ingather']
# ['weather', 'whereat', 'wreathe']
# ['deposit', 'dopiest', 'podites', 'posited', 'sopited', 'topside']
# ['paddlers', 'spraddle']
# ['salty', 'slaty']
# ['sault', 'talus']
# ['penster', 'present', 'repents', 'serpent']
# ['averts', 'starve', 'traves', 'vaster']
# ['agreed', 'dragee', 'geared']
# ['hanker', 'harken']
# ['guilders', 'sludgier']
# ['hoddens', 'shodden']
# ['obdurate', 'taboured']
# ['aurei', 'uraei']
# ['amitroles', 'rolamites']
# ['arise', 'raise', 'serai']
# ['fisted', 'sifted']
# ['annelids', 'lindanes']
# ['frises', 'serifs']
# ['burying', 'rubying']
# ['sir', 'sri']
# ['lout', 'tolu']
# ['animal', 'lamina', 'manila']
# ['purist', 'upstir']
# ['lamias', 'salami']
# ['detours', 'dourest', 'redouts', 'rousted']
# ['basally', 'salably']
# ['devourer', 'overrude']
# ['crafted', 'fracted']
# ['feather', 'terefah']
# ['intwist', 'nitwits']
# ['upwind', 'windup']
# ['boulle', 'lobule']
# ['blowfish', 'fishbowl']
# ['burden', 'burned', 'unbred']
# ['fists', 'sifts']
# ['restless', 'tressels']
# ['boasts', 'sabots']
# ['coax', 'coxa']
# ['arco', 'orca']
# ['coat', 'taco']
# ['conative', 'invocate']
# ['hucks', 'shuck']
# ['maroons', 'romanos']
# ['sallying', 'signally', 'slangily']
# ['bored', 'orbed', 'robed']
# ['adherer', 'reheard']
# ['adheres', 'headers', 'hearsed', 'sheared']
# ['earthed', 'hearted']
# ['falsest', 'fatless']
# ['phytoid', 'typhoid']
# ['calamint', 'claimant']
# ['grumose', 'morgues']
# ['reseaus', 'ureases']
# ['moisteners', 'remoistens']
# ['trout', 'tutor']
# ['calumnies', 'masculine']
# ['optics', 'picots', 'topics']
# ['chatter', 'ratchet']
# ['colin', 'nicol']
# ['lorises', 'rissole']
# ['estriol', 'loiters', 'toilers']
# ['delights', 'slighted']
# ['corelated', 'relocated']
# ['dailies', 'liaised', 'sedilia']
# ['keesters', 'skeeters']
# ['demurest', 'mustered']
# ['maroon', 'romano']
# ['satyrs', 'strays']
# ['argots', 'groats']
# ['cullions', 'scullion']
# ['tackling', 'talcking']
# ['inspan', 'pinnas']
# ['gingery', 'greying']
# ['swiping', 'wisping']
# ['gingers', 'niggers', 'serging', 'snigger']
# ['irksome', 'smokier']
# ['douses', 'soused']
# ['overneat', 'renovate']
# ['swisher', 'wishers']
# ['shivers', 'shrives']
# ['carlines', 'lanciers']
# ['owe', 'woe']
# ['foetors', 'footers']
# ['ribbon', 'robbin']
# ['portend', 'protend']
# ['crier', 'ricer']
# ['cries', 'icers', 'rices']
# ['citer', 'recti', 'trice']
# ['curie', 'ureic']
# ['paseo', 'psoae']
# ['runs', 'urns']
# ['modelers', 'morseled', 'remodels']
# ['eaten', 'enate']
# ['patroon', 'pronota']
# ['lapins', 'plains', 'spinal']
# ['retirers', 'terriers']
# ['polyesters', 'proselytes']
# ['cloture', 'clouter', 'coulter']
# ['isocheims', 'isochimes']
# ['precis', 'prices', 'spicer']
# ['assist', 'stasis']
# ['cellarers', 'recallers']
# ['chapes', 'cheaps']
# ['eparch', 'preach']
# ['alant', 'natal']
# ['alans', 'anlas', 'nasal']
# ['rubato', 'tabour']
# ['pinite', 'tiepin']
# ['armed', 'derma', 'dream', 'madre']
# ['dames', 'meads']
# ['mated', 'tamed']
# ['admen', 'amend', 'maned', 'menad', 'named']
# ['basis', 'bassi', 'isbas']
# ['poetiser', 'poetries']
# ['tephra', 'teraph', 'threap']
# ['wander', 'warden', 'warned']
# ['redans', 'sander', 'snared']
# ['bore', 'robe']
# ['evertors', 'restrove']
# ['outstand', 'standout']
# ['fastback', 'fatbacks']
# ['ardencies', 'increased']
# ['biller', 'rebill']
# ['blubber', 'bubbler']
# ['ameers', 'ramees', 'seamer']
# ['dingles', 'engilds', 'singled']
# ['glinted', 'tingled']
# ['dueling', 'eluding', 'indulge']
# ['anserous', 'arsenous']
# ['assentor', 'senators', 'starnose', 'treasons']
# ['henries', 'inheres']
# ['nerved', 'vender']
# ['torts', 'trots']
# ['carhop', 'coprah']
# ['aphides', 'diphase']
# ['arsenites', 'resinates', 'stearines']
# ['moistening', 'monetising']
# ['bridally', 'ribaldly']
# ['dataries', 'radiates']
# ['hams', 'mash', 'sham']
# ['hero', 'hoer']
# ['hoes', 'hose', 'shoe']
# ['fraters', 'rafters', 'strafer']
# ['dinar', 'drain', 'nadir', 'ranid']
# ['hearings', 'hearsing', 'shearing']
# ['divan', 'viand']
# ['belayed', 'dyeable']
# ['belated', 'bleated']
# ['cereal', 'relace']
# ['conveyers', 'reconveys']
# ['incepts', 'inspect', 'pectins']
# ['norths', 'thorns']
# ['sachets', 'scathes']
# ['diol', 'idol', 'lido']
# ['cadasters', 'cadastres']
# ['mussels', 'sumless']
# ['gowaned', 'wagoned']
# ['dares', 'dears', 'rased', 'reads']
# ['darer', 'drear']
# ['wader', 'wared']
# ['drave', 'raved']
# ['dater', 'derat', 'rated', 'tared', 'trade', 'tread']
# ['deary', 'deray', 'rayed', 'ready']
# ['opsonins', 'sponsion']
# ['bedels', 'bleeds']
# ['cesiums', 'miscues']
# ['bedell', 'belled']
# ['blisters', 'bristles']
# ['balmiest', 'bimetals', 'timbales']
# ['earthset', 'theaters', 'theatres']
# ['night', 'thing']
# ['caveat', 'vacate']
# ['appulse', 'papules', 'upleaps']
# ['baritones', 'obtainers', 'reobtains', 'taborines']
# ['gemmier', 'gremmie', 'immerge']
# ['escheat', 'teaches']
# ['pinchers', 'pinscher']
# ['joram', 'major']
# ['cuif', 'fuci']
# ['mays', 'yams']
# ['maws', 'swam']
# ['mast', 'mats', 'tams']
# ['chancres', 'cranches']
# ['antis', 'saint', 'satin', 'stain', 'tains']
# ['savin', 'vinas']
# ['swain', 'wains']
# ['esparto', 'proteas', 'seaport']
# ['interlopes', 'repletions']
# ['gorge', 'grego']
# ['carpeting', 'preacting']
# ['impaler', 'impearl', 'lempira', 'palmier']
# ['antes', 'etnas', 'nates', 'neats', 'stane']
# ['avens', 'naves', 'vanes']
# ['sewan', 'wanes', 'weans']
# ['sleetiest', 'steeliest']
# ['agas', 'saga']
# ['agar', 'raga']
# ['hermit', 'mither']
# ['arcing', 'caring', 'racing']
# ['retrims', 'trimers']
# ['cering', 'cringe']
# ['closest', 'closets']
# ['imaginer', 'migraine']
# ['donsie', 'noised', 'onside']
# ['dinero', 'ironed']
# ['opined', 'ponied']
# ['bole', 'lobe']
# ['aerology', 'areology']
# ['conked', 'nocked']
# ['blue', 'lube']
# ['belt', 'blet']
# ['blunge', 'bungle']
# ['lilting', 'tilling']
# ['chivies', 'vichies']
# ['easting', 'eatings', 'ingates', 'ingesta', 'seating', 'teasing']
# ['oralities', 'solitaire']
# ['cinques', 'quinces']
# ['flexures', 'refluxes']
# ['logotypies', 'typologies']
# ['drails', 'lairds', 'liards', 'lidars']
# ['rees', 'seer', 'sere']
# ['rete', 'tree']
# ['ever', 'veer']
# ['ewer', 'weer', 'were']
# ['levering', 'reveling']
# ['eery', 'eyer', 'eyre']
# ['charades', 'hardcase']
# ['oinomels', 'simoleon']
# ['genre', 'green']
# ['dossil', 'sloids', 'solids']
# ['proteides', 'redeposit', 'reposited']
# ['bios', 'obis']
# ['destining', 'indigents']
# ['misrated', 'readmits']
# ['rattan', 'tantra', 'tartan']
# ['overstirs', 'servitors']
# ['countered', 'recounted']
# ['assentors', 'starnoses']
# ['skate', 'stake', 'steak', 'takes', 'teaks']
# ['askew', 'wakes', 'wekas']
# ['allotted', 'totalled']
# ['bugles', 'bulges']
# ['befinger', 'befringe']
# ['lumpy', 'plumy']
# ['ampler', 'palmer']
# ['hapless', 'plashes']
# ['direst', 'driest', 'stride']
# ['galiots', 'latigos']
# ['shuting', 'tushing', 'unsight']
# ['hangers', 'rehangs']
# ['dams', 'mads']
# ['farcie', 'fiacre']
# ['facile', 'fecial']
# ['wirer', 'wrier']
# ['refits', 'resift', 'rifest', 'sifter', 'strife']
# ['epistle', 'pelites']
# ['altruism', 'muralist', 'ultraism']
# ['pismire', 'primsie']
# ['epic', 'pice']
# ['blunders', 'bundlers']
# ['aphelion', 'phelonia']
# ['coattails', 'tailcoats']
# ['destains', 'sandiest']
# ['partans', 'tarpans', 'trapans']
# ['coyotes', 'oocytes']
# ['emerita', 'emirate', 'meatier']
# ['seamier', 'seriema']
# ['toeholds', 'toolshed']
# ['deaved', 'evaded']
# ['deaden', 'deaned']
# ['delead', 'leaded']
# ['citreous', 'outcries']
# ['evictors', 'vortices']
# ['excitors', 'exorcist']
# ['farmed', 'framed']
# ['leers', 'reels']
# ['befleaed', 'feedable']
# ['elver', 'lever', 'revel']
# ['licks', 'slick']
# ['girding', 'griding', 'ridging']
# ['predicts', 'scripted']
# ['decide', 'deiced']
# ['shuted', 'tushed']
# ['deduce', 'deuced', 'educed']
# ['abbe', 'babe']
# ['meristem', 'stemmier']
# ['ape', 'pea']
# ['sae', 'sea']
# ['are', 'ear', 'era']
# ['ate', 'eat', 'eta', 'tae', 'tea']
# ['awe', 'wae']
# ['aye', 'yea']
# ['age', 'gae']
# ['ale', 'lea']
# ['ane', 'nae']
# ['bipolar', 'parboil']
# ['garments', 'margents']
# ['longships', 'sploshing']
# ['filmset', 'leftism']
# ['liter', 'litre', 'relit', 'tiler']
# ['liers', 'riels', 'riles', 'slier']
# ['ephas', 'heaps', 'phase', 'shape']
# ['certitude', 'rectitude']
# ['choker', 'hocker']
# ['crocus', 'occurs', 'succor']
# ['demotion', 'motioned']
# ['unions', 'unison']
# ['alienist', 'litanies']
# ['dented', 'tended']
# ['denude', 'dudeen', 'duende', 'endued']
# ['redden', 'rended']
# ['clocking', 'cockling']
# ['depend', 'pended']
# ['albicore', 'cabriole']
# ['clutch', 'cultch']
# ['cupid', 'pudic']
# ['resmooths', 'smoothers']
# ['elans', 'lanes', 'leans']
# ['learn', 'renal']
# ['laten', 'leant']
# ['navel', 'venal']
# ['alone', 'anole']
# ['enisle', 'ensile', 'senile']
# ['lierne', 'reline']
# ['levirate', 'relative']
# ['laterite', 'literate']
# ['didoes', 'diodes']
# ['devoid', 'voided']
# ['hangover', 'overhang']
# ['feistier', 'ferities', 'fieriest']
# ['respects', 'scepters', 'sceptres', 'specters', 'spectres']
# ['esteems', 'mestees']
# ['keens', 'knees', 'skeen', 'skene']
# ['balms', 'lambs']
# ['conserving', 'conversing']
# ['censored', 'encoders', 'necrosed', 'seconder']
# ['innovate', 'venation']
# ['suint', 'units']
# ['stint', 'tints']
# ['bur', 'rub']
# ['nurse', 'runes']
# ['nerts', 'rents', 'stern', 'terns']
# ['filers', 'fliers', 'lifers', 'rifles']
# ['filter', 'lifter', 'trifle']
# ['clingy', 'glycin']
# ['reworks', 'workers']
# ['littorals', 'tortillas']
# ['moistened', 'monetised']
# ['unlives', 'unveils']
# ['burgs', 'grubs']
# ['crustal', 'curtals']
# ['cilice', 'icicle']
# ['desex', 'dexes', 'sexed']
# ['sewed', 'swede', 'weeds']
# ['keen', 'knee']
# ['ceriums', 'murices']
# ['laming', 'lingam', 'malign']
# ['accrues', 'accuser']
# ['cruets', 'cruset', 'curets', 'eructs', 'rectus', 'recuts', 'truces']
# ['entireties', 'eternities']
# ['drillers', 'redrills']
# ['resorts', 'rosters', 'sorters']
# ['assenter', 'earnests', 'sarsenet']
# ['livyers', 'silvery']
# ['fizzers', 'frizzes']
# ['renting', 'ringent']
# ['starrier', 'tarriers']
# ['bailer', 'librae']
# ['igloos', 'isolog']
# ['betokens', 'steenbok']
# ['swaps', 'wasps']
# ['peri', 'pier', 'ripe']
# ['pies', 'sipe']
# ['astatine', 'sanitate']
# ['baryte', 'betray']
# ['palmette', 'template']
# ['gnu', 'gun']
# ['elutions', 'outlines']
# ['nougats', 'outsang']
# ['barkier', 'brakier']
# ['carvels', 'clavers']
# ['ringlets', 'sterling', 'tinglers']
# ['missel', 'slimes', 'smiles']
# ['imputers', 'stumpier']
# ['reseeks', 'seekers']
# ['hematics', 'mastiche', 'misteach']
# ['ottar', 'tarot']
# ['dreed', 'reded']
# ['elision', 'isoline', 'lionise']
# ['havens', 'shaven']
# ['hasten', 'snathe', 'thanes']
# ['outstands', 'standouts']
# ['kales', 'lakes', 'leaks', 'slake']
# ['chattery', 'trachyte']
# ['settee', 'testee']
# ['steeve', 'vestee']
# ['sticklers', 'strickles']
# ['genies', 'seeing']
# ['riot', 'tiro', 'tori', 'trio']
# ['bowmen', 'enwomb']
# ['actuator', 'autocrat']
# ['certes', 'erects', 'resect', 'secret', 'terces']
# ['cereus', 'ceruse', 'recuse', 'rescue', 'secure']
# ['disclike', 'sicklied']
# ['assaying', 'gainsays']
# ['datos', 'doats', 'toads']
# ['defeater', 'federate', 'redefeat']
# ['gloater', 'legator']
# ['mailers', 'realism', 'remails']
# ['maltier', 'marlite']
# ['chis', 'ichs']
# ['chit', 'itch']
# ['chin', 'inch']
# ['paltry', 'partly', 'raptly']
# ['ambones', 'bemoans']
# ['purls', 'slurp']
# ['hailed', 'halide']
# ['deaf', 'fade']
# ['kolas', 'skoal']
# ['foremast', 'formates']
# ['goiter', 'goitre']
# ['enrol', 'loner', 'nerol']
# ['estrays', 'stayers']
# ['starets', 'staters', 'tasters']
# ['putters', 'sputter']
# ['pashes', 'phases', 'shapes']
# ['erased', 'reseda', 'seared']
# ['dearer', 'reader', 'reared', 'redear', 'reread']
# ['redate', 'teared']
# ['evader', 'reaved']
# ['kleig', 'klieg']
# ['aircrews', 'airscrew']
# ['swingles', 'wingless']
# ['glistens', 'singlets']
# ['rester', 'terser']
# ['revers', 'server', 'verser']
# ['girdling', 'ridgling']
# ['pendular', 'underlap', 'uplander']
# ['patrols', 'portals']
# ['ailerons', 'alienors']
# ['oriental', 'relation']
# ['demitasse', 'misseated']
# ['flooders', 'refloods']
# ['orbitals', 'strobila']
# ['altitudes', 'latitudes']
# ['gentil', 'tingle']
# ['ingles', 'single']
# ['quinnat', 'quintan']
# ['eloign', 'legion']
# ['bawled', 'blawed']
# ['cities', 'iciest']
# ['reupholsters', 'upholsterers']
# ['rate', 'tare', 'tear']
# ['aver', 'rave', 'vera']
# ['ware', 'wear']
# ['rare', 'rear']
# ['ares', 'arse', 'ears', 'eras', 'rase', 'sear', 'sera']
# ['aery', 'eyra', 'yare', 'year']
# ['umbellar', 'umbrella']
# ['pules', 'pulse']
# ['pelts', 'slept', 'spelt']
# ['acid', 'cadi', 'caid']
# ['aced', 'cade', 'dace']
# ['cads', 'scad']
# ['arching', 'chagrin', 'charing']
# ['lists', 'silts', 'slits']
# ['akin', 'kain']
# ['cackled', 'clacked']
# ['estreating', 'integrates']
# ['shirty', 'thyrsi', 'yirths']
# ['coiffe', 'office']
# ['ashlers', 'lashers', 'slasher']
# ['halters', 'harslet', 'lathers', 'slather', 'thalers']
# ['peltry', 'pertly']
# ['dashers', 'shaders']
# ['dearths', 'hardest', 'hardset', 'hatreds', 'threads', 'trashed']
# ['orderer', 'reorder']
# ['deworm', 'wormed']
# ['eoliths', 'holiest', 'hostile']
# ['sieving', 'viseing']
# ['hisser', 'shiers', 'shires']
# ['cargoes', 'corsage', 'socager']
# ['sow', 'wos']
# ['deperm', 'premed']
# ['integer', 'treeing']
# ['reeving', 'regiven', 'veering']
# ['lefter', 'reflet', 'telfer']
# ['drawer', 'redraw', 'reward', 'warder', 'warred']
# ['darter', 'retard', 'tarred', 'trader']
# ['fleers', 'refels']
# ['blouses', 'boluses']
# ['negatons', 'tonnages']
# ['caller', 'cellar', 'recall']
# ['farfel', 'raffle']
# ['lentisk', 'tinkles']
# ['welkins', 'winkles']
# ['asset', 'easts', 'sates', 'seats', 'tasse']
# ['saves', 'vases']
# ['marmites', 'rammiest']
# ['gurshes', 'gushers']
# ['indenter', 'intender', 'interned']
# ['stouten', 'tenutos']
# ['bounced', 'buncoed']
# ['duffer', 'ruffed']
# ['cense', 'scene']
# ['monetize', 'zonetime']
# ['liernes', 'relines']
# ['meagerly', 'meagrely']
# ['rethread', 'threader']
# ['hosts', 'shots', 'soths']
# ['deformer', 'reformed']
# ['moorwort', 'tomorrow', 'wormroot']
# ['reliving', 'reviling']
# ['garrison', 'roarings']
# ['sparlings', 'springals']
# ['cineol', 'enolic']
# ['bordello', 'doorbell']
# ['leucin', 'nuclei']
# ['client', 'lentic']
# ['drupe', 'duper', 'perdu', 'prude']
# ['platefuls', 'platesful']
# ['wettish', 'whitest']
# ['maintop', 'ptomain', 'tampion', 'timpano']
# ['parkings', 'sparking']
# ['pariah', 'raphia']
# ['delimits', 'limiteds']
# ['patterers', 'pretreats']
# ['croupe', 'recoup']
# ['maligned', 'medaling']
# ['bustic', 'cubist', 'cubits']
# ['aspersed', 'repassed']
# ['depraves', 'pervades']
# ['carers', 'racers', 'scarer']
# ['carter', 'crater', 'tracer']
# ['carver', 'craver']
# ['banes', 'beans']
# ['easters', 'reseats', 'searest', 'seaters', 'teasers', 'tessera']
# ['oafs', 'sofa']
# ['foundered', 'refounded']
# ['colored', 'decolor']
# ['rewarms', 'swarmer', 'warmers']
# ['ads', 'sad']
# ['dap', 'pad']
# ['brede', 'breed']
# ['chamiso', 'chamois']
# ['argentic', 'catering', 'creating', 'reacting']
# ['eternise', 'teensier']
# ['enumerations', 'mountaineers']
# ['bordellos', 'doorbells']
# ['attars', 'strata']
# ['antimosquito', 'misquotation']
# ['ascertain', 'craniates', 'sectarian']
# ['savoriest', 'travoises']
# ['defray', 'frayed']
# ['fugled', 'gulfed']
# ['asperges', 'presages']
# ['leets', 'sleet', 'steel', 'stele', 'teles']
# ['fodgel', 'golfed']
# ['abeam', 'ameba']
# ['outraging', 'ragouting']
# ['punier', 'purine', 'unripe']
# ['dugong', 'gundog']
# ['ferule', 'fueler', 'refuel']
# ['clipper', 'cripple']
# ['clodpoles', 'scolloped']
# ['abets', 'baste', 'bates', 'beast', 'beats', 'betas', 'tabes']
# ['abuse', 'beaus']
# ['bases', 'sabes']
# ['gallate', 'galleta', 'tallage']
# ['saltiness', 'stainless']
# ['littering', 'retitling']
# ['gatherer', 'regather']
# ['blimy', 'limby']
# ['acerb', 'brace', 'caber']
# ['shops', 'sophs']
# ['phots', 'tophs']
# ['hypos', 'sophy']
# ['islet', 'istle', 'stile', 'tiles']
# ['outsells', 'sellouts']
# ['outputs', 'putouts']
# ['spites', 'stipes']
# ['recorder', 'rerecord']
# ['esthetic', 'techiest']
# ['molts', 'smolt']
# ['blister', 'bristle', 'riblets']
# ['rewinds', 'winders']
# ['abhorrer', 'harborer']
# ['welkin', 'winkle']
# ['chits', 'stich']
# ['hones', 'hosen', 'nohes', 'shone']
# ['heron', 'honer']
# ['deifier', 'edifier', 'reified']
# ['cesspit', 'septics']
# ['bedrooms', 'boredoms']
# ['amenity', 'anytime']
# ['inviters', 'vitrines']
# ['analgesic', 'angelicas']
# ['bescour', 'obscure']
# ['lousier', 'soilure']
# ['encodes', 'seconde']
# ['encoder', 'encored']
# ['amnic', 'manic']
# ['maulers', 'serumal']
# ['armlets', 'lamster', 'tramels']
# ['dignifies', 'signified']
# ['einkorns', 'nonskier']
# ['degums', 'smudge']
# ['donor', 'rondo']
# ['capsule', 'specula']
# ['denier', 'nereid', 'reined']
# ['herried', 'rehired']
# ['demur', 'mured']
# ['entirety', 'eternity']
# ['instars', 'santirs', 'strains']
# ['elevators', 'levatores']
# ['cone', 'once']
# ['retwist', 'twister']
# ['stretti', 'titters', 'tritest']
# ['dioptric', 'tripodic']
# ['mestinoes', 'monetises', 'semitones']
# ['codlings', 'lingcods', 'scolding']
# ['bespake', 'bespeak']
# ['pretasted', 'spattered']
# ['suitings', 'tissuing']
# ['retrials', 'trailers']
# ['rondure', 'rounder']
# ['etyma', 'matey', 'meaty']
# ['rattles', 'starlet', 'startle']
# ['estrual', 'saluter']
# ['travels', 'varlets', 'vestral']
# ['warstle', 'wastrel', 'wrastle']
# ['blungers', 'bunglers']
# ['arsino', 'norias']
# ['puns', 'spun']
# ['impersonate', 'permeations']
# ['argles', 'glares', 'lagers', 'larges']
# ['demeans', 'seedman']
# ['amender', 'meander', 'renamed']
# ['bearded', 'breaded']
# ['maximin', 'minimax']
# ['dewinesses', 'widenesses']
# ['inklings', 'slinking']
# ['loader', 'ordeal', 'reload']
# ['incloser', 'licensor']
# ['allures', 'laurels']
# ['bars', 'bras']
# ['jingko', 'joking']
# ['aldols', 'allods']
# ['dallier', 'dialler', 'rallied']
# ['layovers', 'overlays']
# ['mestino', 'moisten']
# ['buds', 'dubs']
# ['intitles', 'lintiest']
# ['horseman', 'menorahs', 'rhamnose']
# ['carolling', 'collaring']
# ['girts', 'grist', 'grits', 'trigs']
# ['opposing', 'pogonips']
# ['torpedo', 'trooped']
# ['pays', 'pyas', 'spay', 'yaps']
# ['asps', 'pass', 'saps', 'spas']
# ['paws', 'swap', 'waps', 'wasp']
# ['past', 'pats', 'spat', 'taps']
# ['offset', 'setoff']
# ['lums', 'slum']
# ['reasons', 'senoras']
# ['atoners', 'senator', 'treason']
# ['platans', 'saltpan']
# ['rescuers', 'securers']
# ['asperse', 'pareses', 'serapes']
# ['amulets', 'muletas']
# ['acierated', 'eradicate']
# ['reissue', 'seisure']
# ['eyras', 'resay', 'sayer', 'years']
# ['aster', 'rates', 'stare', 'tares', 'tears']
# ['aures', 'urase', 'ureas', 'ursae']
# ['avers', 'raves', 'saver']
# ['resaw', 'sawer', 'sewar', 'sware', 'swear', 'wares', 'wears']
# ['arses', 'rases', 'sears']
# ['gars', 'rags']
# ['groupers', 'regroups']
# ['betrayal', 'rateably']
# ['lippens', 'nipples']
# ['caterer', 'recrate', 'retrace', 'terrace']
# ['creditor', 'director']
# ['drags', 'grads']
# ['begins', 'beings', 'binges']
# ['barging', 'garbing']
# ['alumna', 'manual']
# ['engirdles', 'reedlings']
# ['warstling', 'wrastling']
# ['rattlings', 'startling']
# ['brawling', 'warbling']
# ['besotting', 'obtesting']
# ['crepier', 'piercer', 'reprice']
# ['niffers', 'sniffer']
# ['overnew', 'rewoven']
# ['fernier', 'refiner']
# ['maneges', 'menages']
# ['sails', 'sials', 'sisal']
# ['silva', 'vails', 'vials']
# ['swail', 'wails']
# ['alist', 'litas', 'tails']
# ['spumier', 'umpires']
# ['lazes', 'zeals']
# ['axels', 'axles']
# ['laves', 'salve', 'slave', 'vales', 'valse', 'veals']
# ['least', 'setal', 'slate', 'stale', 'steal', 'stela', 'taels', 'tales', 'teals', 'tesla']
# ['lases', 'sales', 'seals']
# ['meristic', 'scimiter', 'trisemic']
# ['mells', 'smell']
# ['collapsing', 'scalloping']
# ['ells', 'sell']
# ['blunged', 'bungled']
# ['absorber', 'reabsorb']
# ['fighter', 'freight', 'refight']
# ['goas', 'sago']
# ['gentrices', 'resecting', 'secreting']
# ['parroty', 'portray']
# ['coenacts', 'cosecant']
# ['snorer', 'sorner']
# ['nonstop', 'pontons']
# ['ritters', 'territs']
# ['enervating', 'venerating']
# ['evolver', 'revolve']
# ['performs', 'preforms']
# ['twiners', 'winters']
# ['netty', 'tenty']
# ['hardener', 'reharden']
# ['chantries', 'snatchier']
# ['aiglets', 'ligates']
# ['glassie', 'ligases', 'silages']
# ['dinars', 'drains', 'nadirs', 'ranids']
# ['licensers', 'silencers']
# ['revenues', 'unreeves']
# ['swound', 'wounds']
# ['courted', 'eductor']
# ['orb', 'rob']
# ['bos', 'sob']
# ['anchor', 'archon', 'rancho']
# ['sweetness', 'wetnesses']
# ['casts', 'scats']
# ['ponders', 'respond']
# ['meson', 'nomes', 'omens']
# ['astonied', 'sedation']
# ['butyls', 'subtly']
# ['mitral', 'ramtil']
# ['gasolier', 'girasole', 'seraglio']
# ['flowering', 'reflowing']
# ['sprightly', 'triglyphs']
# ['curtesy', 'curtsey']
# ['first', 'frits', 'rifts']
# ['peris', 'piers', 'pries', 'prise', 'ripes', 'speir', 'spier', 'spire']
# ['prier', 'riper']
# ['inroad', 'ordain']
# ['mealiest', 'metalise']
# ['maracas', 'marasca', 'mascara']
# ['colonist', 'stolonic']
# ['earthy', 'hearty']
# ['denuder', 'endured']
# ['lading', 'ligand']
# ['nastily', 'saintly']
# ['rapist', 'tapirs']
# ['deposition', 'positioned']
# ['veena', 'venae']
# ['zaniest', 'zeatins']
# ['aunties', 'sinuate']
# ['instate', 'satinet']
# ['tawnies', 'waniest']
# ['metier', 'reemit', 'retime']
# ['corkiest', 'rockiest', 'stockier']
# ['outrun', 'runout']
# ['dissolute', 'solitudes']
# ['swath', 'thaws', 'whats']
# ['swiped', 'wisped']
# ['riving', 'virgin']
# ['rising', 'siring']
# ['moline', 'oilmen']
# ['limens', 'simnel']
# ['however', 'whoever']
# ['colander', 'conelrad']
# ['actings', 'casting']
# ['causing', 'saucing']
# ['coinfer', 'conifer']
# ['cervices', 'crevices']
# ['alsikes', 'asslike']
# ['depone', 'opened']
# ['repins', 'ripens', 'sniper']
# ['demurring', 'murdering']
# ['aspics', 'spicas']
# ['ironies', 'noisier']
# ['gouty', 'guyot']
# ['sauteing', 'unitages']
# ['estating', 'tangiest']
# ['caroches', 'coachers']
# ['pistons', 'postins']
# ['lunatics', 'sultanic']
# ['palliest', 'pastille']
# ['braces', 'cabers']
# ['gatherers', 'regathers']
# ['grouty', 'yogurt']
# ['loam', 'mola']
# ['alum', 'maul']
# ['lamp', 'palm']
# ['alms', 'lams', 'slam']
# ['excepting', 'expecting']
# ['pedantries', 'pedestrian']
# ['aimers', 'armies', 'ramies']
# ['bedsore', 'sobered']
# ['aglee', 'eagle']
# ['kayoed', 'okayed']
# ['clumber', 'crumble']
# ['arsenides', 'readiness']
# ['detainers', 'resinated']
# ['remailed', 'remedial']
# ['empties', 'septime']
# ['settlers', 'sterlets', 'trestles']
# ['fitness', 'infests']
# ['ruing', 'unrig']
# ['snooped', 'spooned']
# ['grandams', 'grandmas']
# ['memos', 'momes']
# ['bounders', 'rebounds', 'suborned']
# ['hirseled', 'relished', 'shielder']
# ['camber', 'crambe']
# ['defilers', 'fielders']
# ['teazel', 'teazle']
# ['dower', 'rowed']
# ['drove', 'roved', 'voder']
# ['doter', 'trode']
# ['assertor', 'assorter', 'oratress', 'reassort', 'roasters']
# ['friary', 'rarify']
# ['manures', 'surname']
# ['chaster', 'rachets', 'ratches']
# ['chasers', 'crashes', 'eschars']
# ['iodines', 'ionised']
# ['manpack', 'packman']
# ['estreat', 'restate', 'retaste']
# ['passee', 'peases']
# ['etapes', 'peseta']
# ['sisterly', 'styliser']
# ['eanlings', 'leanings']
# ['artist', 'strait', 'strati', 'traits']
# ['accruals', 'caraculs', 'saccular']
# ['gaddis', 'gadids']
# ['chattel', 'latchet']
# ['keenest', 'ketenes']
# ['flairs', 'frails']
# ['marbled', 'rambled']
# ['bedlams', 'beldams']
# ['hadjis', 'jadish', 'jihads']
# ['outwash', 'washout']
# ['coitions', 'isotonic']
# ['burier', 'rubier']
# ['darndest', 'stranded']
# ['bayadeer', 'bayadere']
# ['menu', 'neum']
# ['demote', 'emoted']
# ['rapidest', 'traipsed']
# ['meno', 'nome', 'omen']
# ['meeter', 'remeet', 'teemer']
# ['tired', 'tried']
# ['bahadurs', 'subahdar']
# ['saults', 'tussal']
# ['jolters', 'jostler']
# ['closure', 'colures']
# ['colters', 'corslet', 'costrel', 'lectors']
# ['bowers', 'browse']
# ['sorbet', 'strobe']
# ['minsters', 'trimness']
# ['brumal', 'labrum', 'lumbar', 'umbral']
# ['percussion', 'supersonic']
# ['bagel', 'belga', 'gable', 'gleba']
# ['hotting', 'tonight']
# ['gong', 'nogg']
# ['ceriph', 'cipher']
# ['cholera', 'chorale', 'choreal']
# ['destain', 'detains', 'instead', 'sainted', 'stained']
# ['denounce', 'enounced']
# ['harslets', 'slathers']
# ['atomics', 'osmatic', 'somatic']
# ['rowdiness', 'wordiness']
# ['uncases', 'usances']
# ['defiled', 'fielded']
# ['deified', 'edified']
# ['hassel', 'hassle', 'lashes', 'selahs', 'shales', 'sheals']
# ['halest', 'haslet', 'lathes']
# ['whales', 'wheals']
# ['outgrin', 'outring', 'routing', 'touring']
# ['randomize', 'romanized']
# ['envoi', 'ovine']
# ['eosin', 'noise']
# ['outpulls', 'pullouts']
# ['pepos', 'popes']
# ['flusters', 'turfless']
# ['loused', 'souled']
# ['oldest', 'stoled']
# ['dowels', 'slowed']
# ['path', 'phat']
# ['haps', 'hasp', 'pash']
# ['gaoling', 'goaling']
# ['lippings', 'slipping']
# ['drayage', 'yardage']
# ['stout', 'touts']
# ['incised', 'indices']
# ['identic', 'incited']
# ['retainers', 'ternaries']
# ['coffers', 'scoffer']
# ['aristas', 'tarsias']
# ['dewax', 'waxed']
# ['belied', 'edible']
# ['lasting', 'salting', 'slating', 'staling']
# ['abuts', 'tabus', 'tsuba', 'tubas']
# ['idleness', 'linseeds']
# ['enlisted', 'listened', 'tinseled']
# ['dragnet', 'granted']
# ['gnarred', 'grander']
# ['retests', 'setters', 'streets', 'tersest', 'testers']
# ['revests', 'versets', 'verstes']
# ['cipolins', 'picolins']
# ['brokages', 'grosbeak']
# ['becrust', 'becurst']
# ['unite', 'untie']
# ['twine', 'witen']
# ['accepter', 'reaccept']
# ['laments', 'mantels', 'mantles']
# ['rennet', 'tenner']
# ['ammeter', 'metamer']
# ['skirret', 'skirter', 'striker']
# ['pavid', 'vapid']
# ['moorier', 'roomier']
# ['damagers', 'smaragde']
# ['stove', 'votes']
# ['costing', 'gnostic']
# ['fondus', 'founds']
# ['besoms', 'emboss']
# ['arrogant', 'tarragon']
# ['hammerers', 'rehammers']
# ['mover', 'vomer']
# ['mores', 'omers']
# ['coattail', 'tailcoat']
# ['emphasis', 'misshape']
# ['calker', 'lacker', 'rackle']
# ['dendron', 'donnerd']
# ['lomenta', 'omental', 'telamon']
# ['spotlights', 'stoplights']
# ['ceders', 'creeds', 'screed']
# ['satirist', 'sitarist']
# ['enfold', 'fondle']
# ['canfuls', 'cansful']
# ['mortals', 'stromal']
# ['peds', 'sped']
# ['depraved', 'pervaded']
# ['departed', 'predated']
# ['ciliates', 'silicate']
# ['claimed', 'decimal', 'declaim', 'medical']
# ['mistral', 'ramtils']
# ['overtops', 'stopover']
# ['cookouts', 'outcooks']
# ['enigma', 'gamine']
# ['gamier', 'maigre', 'mirage']
# ['inspire', 'spinier']
# ['evened', 'vendee']
# ['deepen', 'peened']
# ['aspic', 'picas', 'spica']
# ['ponderers', 'responder']
# ['sepulchers', 'sepulchres']
# ['dousing', 'guidons']
# ['iron', 'noir']
# ['former', 'reform']
# ['staminal', 'talisman']
# ['oast', 'oats', 'stoa', 'taos']
# ['ceiled', 'decile']
# ['dormins', 'nimrods']
# ['lamister', 'marliest', 'marlites', 'misalter']
# ['resought', 'roughest']
# ['carvel', 'claver']
# ['cartel', 'claret', 'rectal']
# ['carles', 'clears', 'lacers', 'scaler', 'sclera']
# ['ethylic', 'lecythi', 'techily']
# ['orchid', 'rhodic']
# ['retrim', 'trimer']
# ['hammerer', 'rehammer']
# ['ganger', 'grange', 'nagger']
# ['resorter', 'restorer', 'retrorse']
# ['casuals', 'causals']
# ['restring', 'stringer']
# ['giron', 'groin']
# ['conatus', 'toucans']
# ['imposer', 'promise', 'semipro']
# ['elm', 'mel']
# ['quartes', 'quatres']
# ['antisera', 'ratanies', 'seatrain']
# ['gunfires', 'refusing']
# ['nigglings', 'sniggling']
# ['lemuroid', 'mouldier']
# ['dawdlers', 'waddlers']
# ['landings', 'sandling']
# ['literal', 'tallier']
# ['allseeds', 'leadless']
# ['inure', 'urine']
# ['dander', 'darned']
# ['dedans', 'desand', 'sadden', 'sanded']
# ['sheens', 'sneesh']
# ['purin', 'unrip']
# ['digester', 'redigest']
# ['edifiers', 'fireside']
# ['ferritic', 'terrific']
# ['hornet', 'throne']
# ['herons', 'honers', 'nosher', 'senhor']
# ['anuric', 'uranic']
# ['stick', 'ticks']
# ['binders', 'rebinds']
# ['colonies', 'colonise', 'eclosion']
# ['abet', 'bate', 'beat', 'beta']
# ['bare', 'bear', 'brae']
# ['ash', 'has']
# ['hap', 'pah']
# ['haw', 'wha']
# ['bane', 'bean']
# ['able', 'bale', 'blae']
# ['beam', 'bema']
# ['bake', 'beak']
# ['parish', 'raphis']
# ['decants', 'descant', 'scanted']
# ['adducers', 'crusaded']
# ['beglad', 'gabled']
# ['badger', 'barged', 'garbed']
# ['eves', 'vees']
# ['flounders', 'unfolders']
# ['chancier', 'chicaner']
# ['clobber', 'cobbler']
# ['bermes', 'embers']
# ['patricides', 'pediatrics']
# ['bemire', 'berime', 'bireme']
# ['indicter', 'indirect']
# ['abettors', 'taborets']
# ['crowners', 'recrowns']
# ['carpers', 'scarper', 'scraper']
# ['quills', 'squill']
# ['questionnaire', 'questionniare']
# ['prolapses', 'sapropels']
# ['litter', 'tilter']
# ['gammer', 'gramme']
# ['dialings', 'gliadins']
# ['horrent', 'norther']
# ['elastics', 'scaliest']
# ['clues', 'luces']
# ['dewily', 'widely', 'wieldy']
# ['asthenic', 'chanties']
# ['boxwood', 'woodbox']
# ['weathers', 'wreathes']
# ['waives', 'wavies']
# ['unlay', 'yulan']
# ['endow', 'owned']
# ['rundlets', 'trundles']
# ['sculking', 'suckling']
# ['adhered', 'redhead']
# ['ovular', 'valour']
# ['unlive', 'unveil']
# ['animaters', 'marinates']
# ['belaced', 'debacle']
# ['histamine', 'thiamines']
# ['enervation', 'veneration']
# ['ambers', 'breams', 'embars']
# ['carpings', 'scarping', 'scraping']
# ['sayest', 'yeasts']
# ['staves', 'vestas']
# ['sweats', 'tawses', 'wastes']
# ['states', 'tasset', 'tastes']
# ['caiman', 'maniac']
# ['mundane', 'unnamed']
# ['spurt', 'turps']
# ['spaeings', 'spinages']
# ['amides', 'medias']
# ['aidmen', 'daimen', 'maiden', 'median']
# ['gipper', 'grippe']
# ['drumble', 'rumbled']
# ['canvasers', 'canvasser']
# ['pangens', 'penangs']
# ['attendees', 'edentates']
# ['dioptral', 'tripodal']
# ['faults', 'flatus']
# ['cause', 'sauce']
# ['fornicating', 'fractioning']
# ['hidrotic', 'trichoid']
# ['stows', 'swots']
# ['tewed', 'tweed']
# ['redound', 'rounded', 'underdo']
# ['aspiring', 'praising']
# ['earnest', 'eastern', 'nearest']
# ['eth', 'het', 'the']
# ['hes', 'she']
# ['hey', 'yeh']
# ['anthem', 'hetman']
# ['bolster', 'bolters', 'lobster']
# ['spirted', 'striped']
# ['gaddi', 'gadid']
# ['insisted', 'tidiness']
# ['anergias', 'angaries', 'arginase']
# ['diameters', 'dreamiest']
# ['daikers', 'darkies']
# ['parrot', 'raptor']
# ['racists', 'sacrist']
# ['precedent', 'precented']
# ['pastina', 'patinas', 'pinatas', 'taipans']
# ['mantises', 'matiness']
# ['canoe', 'ocean']
# ['caner', 'crane', 'nacre', 'rance']
# ['oyster', 'storey', 'toyers']
# ['escaloped', 'opalesced']
# ['hastener', 'heartens']
# ['exporter', 'reexport']
# ['coif', 'fico', 'foci']
# ['dilaters', 'lardiest']
# ['larum', 'mural']
# ['aggrades', 'saggared']
# ['disabuse', 'subideas']
# ['lengthy', 'thegnly']
# ['winzes', 'wizens']
# ['hallooed', 'holloaed']
# ['loops', 'polos', 'pools', 'sloop', 'spool']
# ['bestud', 'busted', 'debuts']
# ['harms', 'marsh']
# ['devoir', 'voider']
# ['glinting', 'tingling']
# ['singling', 'slinging']
# ['cruiser', 'curries']
# ['bounder', 'rebound', 'unrobed']
# ['laminal', 'manilla']
# ['desert', 'deters', 'rested']
# ['alchymies', 'lechayims']
# ['erecters', 'reerects', 'secreter']
# ['basin', 'nabis', 'sabin']
# ['bairn', 'brain']
# ['adorers', 'drosera']
# ['feckly', 'flecky']
# ['apses', 'pases', 'passe', 'spaes']
# ['paste', 'pates', 'peats', 'septa', 'spate', 'tapes', 'tepas']
# ['detent', 'netted', 'tented']
# ['situs', 'suits']
# ['farceurs', 'surfacer']
# ['reamed', 'remade']
# ['adeems', 'edemas', 'seamed']
# ['croupily', 'polyuric']
# ['sanes', 'sensa']
# ['cithers', 'richest']
# ['lays', 'slay']
# ['bizarres', 'braziers']
# ['arbiters', 'rarebits']
# ['brasiers', 'brassier']
# ['groining', 'ignoring']
# ['fares', 'fears', 'safer']
# ['emitters', 'termites']
# ['curetting', 'recutting']
# ['reign', 'renig']
# ['pallette', 'platelet']
# ['genom', 'gnome']
# ['lustering', 'resulting']
# ['grower', 'regrow']
# ['ceramist', 'matrices', 'mistrace', 'scimetar']
# ['estimated', 'meditates']
# ['alga', 'gala']
# ['chattels', 'latchets']
# ['cruse', 'cures', 'curse', 'ecrus', 'sucre']
# ['surfeits', 'surfiest']
# ['anethol', 'ethanol']
# ['stovers', 'votress']
# ['estrous', 'oestrus', 'ousters', 'sourest', 'souters', 'stoures', 'tussore']
# ['oysters', 'storeys']
# ['openly', 'poleyn']
# ['driller', 'redrill']
# ['rowers', 'worser']
# ['rouser', 'sourer']
# ['prides', 'prised', 'redips', 'spider', 'spired']
# ['stilt', 'tilts']
# ['silty', 'styli']
# ['emoter', 'meteor', 'remote']
# ['termor', 'tremor']
# ['peartest', 'pretaste']
# ['halteres', 'leathers']
# ['manors', 'ramson', 'ransom', 'romans']
# ['bedim', 'imbed']
# ['bidet', 'debit']
# ['bider', 'bride', 'rebid']
# ['classers', 'scarless']
# ['foundering', 'refounding']
# ['bauds', 'daubs']
# ['gels', 'legs']
# ['glue', 'luge']
# ['loge', 'ogle']
# ['cestodes', 'cosseted']
# ['relators', 'restoral']
# ['blastings', 'stablings']
# ['gadgets', 'stagged']
# ['respected', 'sceptered']
# ['gulps', 'plugs']
# ['congaed', 'decagon']
# ['skats', 'tasks']
# ['degust', 'gusted']
# ['floats', 'flotas']
# ['atman', 'manta']
# ['abaters', 'abreast']
# ['misheard', 'semihard']
# ['gloomier', 'oligomer']
# ['gurnet', 'urgent']
# ['articles', 'recitals', 'sterical']
# ['cavilers', 'claviers', 'visceral']
# ['monarch', 'nomarch']
# ['oils', 'silo', 'soil', 'soli']
# ['chorea', 'ochrea', 'orache']
# ['bazars', 'brazas']
# ['recused', 'reduces', 'rescued', 'secured', 'seducer']
# ['humors', 'mohurs']
# ['reddles', 'sledder']
# ['filtrations', 'flirtations']
# ['restock', 'rockets', 'stocker']
# ['stung', 'tungs']
# ['curdle', 'curled']
# ['fouls', 'sulfo']
# ['flows', 'fowls', 'wolfs']
# ['bastioned', 'botanised']
# ['aldol', 'allod']
# ['englut', 'gluten']
# ['caplins', 'inclasp']
# ['nephrite', 'trephine']
# ['chart', 'ratch']
# ['run', 'urn']
# ['travois', 'viators']
# ['duple', 'puled']
# ['charpai', 'haircap']
# ['bacons', 'bancos']
# ['carbon', 'corban']
# ['harts', 'tahrs', 'trash']
# ['coteries', 'esoteric']
# ['couths', 'scouth']
# ['gaped', 'paged']
# ['raunchy', 'unchary']
# ['cowlings', 'scowling']
# ['quinnats', 'quintans']
# ['jeered', 'jereed']
# ['babka', 'kabab']
# ['erection', 'neoteric']
# ['disease', 'seaside']
# ['endue', 'undee']
# ['avenge', 'geneva']
# ['enrage', 'genera']
# ['agenes', 'senega']
# ['headpin', 'pinhead']
# ['aggrade', 'garaged']
# ['espousal', 'sepalous']
# ['presell', 'respell', 'speller']
# ['mirks', 'smirk']
# ['concerting', 'concreting']
# ['bruiters', 'burriest']
# ['muteness', 'tenesmus']
# ['wigglers', 'wriggles']
# ['cahiers', 'cashier']
# ['beaut', 'tubae']
# ['berated', 'debater', 'rebated', 'tabered']
# ['drayman', 'yardman']
# ['cerate', 'create', 'ecarte']
# ['heeders', 'heredes', 'sheered']
# ['anears', 'arenas']
# ['evokers', 'revokes']
# ['lecturing', 'relucting']
# ['legalism', 'millages']
# ['anethols', 'ethanols']
# ['funfairs', 'ruffians']
# ['merises', 'messier', 'remises']
# ['metiers', 'reemits', 'retimes', 'triseme']
# ['mirexes', 'remixes']
# ['dunite', 'united', 'untied']
# ['beys', 'byes']
# ['best', 'bets']
# ['drafters', 'redrafts']
# ['chiders', 'herdics']
# ['castes', 'cestas']
# ['actinons', 'canonist', 'contains', 'sanction', 'sonantic']
# ['tinstone', 'tontines']
# ['amerces', 'racemes']
# ['add', 'dad']
# ['charts', 'starch']
# ['rues', 'ruse', 'suer', 'sure', 'user']
# ['alp', 'lap', 'pal']
# ['colpitis', 'politics', 'psilotic']
# ['meriting', 'mitering', 'retiming']
# ['hikers', 'shriek', 'shrike']
# ['conduits', 'discount', 'noctuids']
# ['dermas', 'dreams', 'madres']
# ['dreamt', 'marted']
# ['luteum', 'mutuel', 'mutule']
# ['argled', 'glared']
# ['gaoled', 'goaled']
# ['angled', 'dangle', 'lagend']
# ['dowsers', 'drowses']
# ['borings', 'sorbing']
# ['dossers', 'drosses']
# ['mobiles', 'obelism']
# ['grieves', 'regives']
# ['oestrums', 'strumose']
# ['sirs', 'sris']
# ['kinship', 'pinkish']
# ['pentoses', 'posteens']
# ['dresser', 'redress']
# ['nape', 'neap', 'pane', 'pean']
# ['raser', 'rears']
# ['earn', 'near']
# ['battue', 'tubate']
# ['altho', 'loath', 'lotah']
# ['halos', 'shoal']
# ['oaring', 'onagri', 'origan']
# ['amiss', 'simas']
# ['maist', 'tamis']
# ['rater', 'tarre', 'terra']
# ['bluster', 'butlers', 'subtler']
# ['asperating', 'separating']
# ['dined', 'nided']
# ['mazes', 'smaze']
# ['masse', 'mesas', 'seams']
# ['algae', 'galea']
# ['impanels', 'maniples']
# ['proofers', 'reproofs']
# ['rapparee', 'reappear']
# ['miring', 'riming']
# ['cions', 'coins', 'icons', 'scion', 'sonic']
# ['greasy', 'yagers']
# ['gasser', 'sarges']
# ['swager', 'wagers']
# ['grates', 'greats', 'stager', 'targes']
# ['corsages', 'socagers']
# ['agminate', 'enigmata']
# ['inverters', 'restriven']
# ['reuniters', 'turneries']
# ['galore', 'gaoler']
# ['glomera', 'gomeral']
# ['overdoes', 'overdose']
# ['imbrutes', 'resubmit', 'terbiums']
# ['ilmenites', 'melinites']
# ['motets', 'mottes', 'totems']
# ['masseter', 'seamster', 'steamers']
# ['hokes', 'okehs']
# ['drag', 'grad']
# ['dago', 'goad']
# ['leprotic', 'petrolic']
# ['duds', 'sudd']
# ['colones', 'console']
# ['lapser', 'parles', 'pearls']
# ['palter', 'plater']
# ['parley', 'pearly', 'player', 'replay']
# ['biggin', 'gibing']
# ['ephedrins', 'insphered', 'phrensied']
# ['tower', 'wrote']
# ['overt', 'trove', 'voter']
# ['otter', 'torte', 'toter']
# ['depositor', 'droopiest']
# ['emotions', 'mooniest']
# ['gradient', 'redating', 'treading']
# ['aunt', 'tuna']
# ['diametric', 'matricide']
# ['consigned', 'seconding']
# ['codeins', 'secondi']
# ['astheny', 'shantey']
# ['feyer', 'reefy']
# ['feres', 'frees', 'reefs']
# ['freer', 'frere', 'refer']
# ['alterant', 'tarletan']
# ['betided', 'debited']
# ['isatines', 'sanities', 'sanitise', 'teniasis']
# ['loather', 'rathole']
# ['anadems', 'maenads']
# ['limos', 'milos', 'moils']
# ['restive', 'veriest']
# ['along', 'logan']
# ['glans', 'slang']
# ['enjoyer', 'reenjoy']
# ['emeers', 'seemer']
# ['assort', 'roasts']
# ['fatsos', 'softas']
# ['cam', 'mac']
# ['arc', 'car']
# ['cap', 'pac']
# ['act', 'cat']
# ['derris', 'driers', 'riders']
# ['ad', 'da']
# ['ah', 'ha']
# ['an', 'na']
# ['at', 'ta']
# ['ay', 'ya']
# ['cleansers', 'clearness']
# ['considerate', 'desecration']
# ['chorions', 'isochron']
# ['eelgrass', 'gearless', 'largesse']
# ['housetops', 'pothouses']
# ['questor', 'quoters', 'roquets', 'torques']
# ['tephras', 'threaps']
# ['phrases', 'seraphs', 'shapers']
# ['bestowal', 'stowable', 'teabowls']
# ['canula', 'lacuna']
# ['capitols', 'coalpits']
# ['exalt', 'latex']
# ['knops', 'knosp']
# ['marishes', 'mishears']
# ['apices', 'spicae']
# ['laymen', 'meanly', 'namely']
# ['banger', 'graben']
# ['gluers', 'gruels']
# ['argents', 'garnets', 'strange']
# ['builders', 'rebuilds']
# ['bristled', 'driblets']
# ['espies', 'peises', 'speise']
# ['oilcup', 'upcoil']
# ['actor', 'taroc']
# ['siped', 'spied']
# ['botanies', 'botanise', 'obeisant']
# ['abelmosk', 'smokable']
# ['kinglier', 'ringlike']
# ['pupils', 'slipup']
# ['gisarme', 'mirages']
# ['dhole', 'holed']
# ['rooster', 'rooters', 'toreros']
# ['restamps', 'stampers']
# ['excitation', 'intoxicate']
# ['loggings', 'slogging']
# ['stork', 'torsk']
# ['frenetic', 'infecter', 'reinfect']
# ['ooziness', 'ozonises']
# ['entia', 'tenia', 'tinea']
# ['naevi', 'naive']
# ['abmhos', 'abohms']
# ['repenters', 'represent']
# ['ozonides', 'ozonised']
# ['deriver', 'redrive']
# ['rewired', 'weirder']
# ['retired', 'retried', 'tireder']
# ['derries', 'desirer', 'redries', 'resider', 'serried']
# ['autoing', 'outgain']
# ['intervening', 'reinventing']
# ['revamp', 'vamper']
# ['candle', 'lanced']
# ['calmed', 'macled']
# ['decals', 'scaled']
# ['cradle', 'credal', 'reclad']
# ['imbrute', 'terbium']
# ['caudle', 'cedula']
# ['stewing', 'twinges', 'westing']
# ['setting', 'testing']
# ['introduce', 'reduction']
# ['grasps', 'sprags']
# ['glutted', 'guttled']
# ['consorted', 'creodonts']
# ['fasteners', 'refastens']
# ['dishing', 'hidings', 'shindig']
# ['apostil', 'topsail']
# ['filterers', 'refilters']
# ['linos', 'lions', 'loins', 'noils']
# ['coset', 'cotes', 'escot']
# ['nilgais', 'sailing']
# ['lairing', 'railing']
# ['intagli', 'tailing']
# ['alining', 'nailing']
# ['helves', 'shelve']
# ['lamisters', 'misalters']
# ['elations', 'insolate', 'toenails']
# ['doilies', 'idolise']
# ['pother', 'thorpe']
# ['ephors', 'hopers', 'posher']
# ['cauldron', 'crunodal']
# ['strette', 'tetters']
# ['burble', 'lubber', 'rubble']
# ['ethologies', 'theologies']
# ['decimate', 'medicate']
# ['ammines', 'misname']
# ['wadder', 'warded']
# ['iolites', 'oiliest']
# ['awes', 'waes']
# ['ayes', 'easy', 'eyas', 'yeas']
# ['barbless', 'slabbers']
# ['eastings', 'giantess', 'seatings']
# ['hooks', 'shook']
# ['azotemic', 'metazoic']
# ['estate', 'testae']
# ['prelacies', 'specialer']
# ['igloo', 'logoi']
# ['restrings', 'stringers']
# ['enervated', 'venerated']
# ['pileup', 'uppile']
# ['lipper', 'ripple']
# ['hops', 'posh', 'shop', 'soph']
# ['phot', 'toph']
# ['nodose', 'noosed', 'odeons']
# ['heaves', 'sheave']
# ['cents', 'scent']
# ['briskest', 'briskets']
# ['ages', 'gaes', 'sage']
# ['ager', 'gear', 'rage']
# ['gape', 'page', 'peag']
# ['gaen', 'gane']
# ['game', 'mage']
# ['egal', 'gale']
# ['collude', 'loculed']
# ['adorners', 'readorns']
# ['ancon', 'canon']
# ['annelid', 'lindane']
# ['acne', 'cane']
# ['alec', 'lace']
# ['aces', 'case']
# ['cape', 'pace']
# ['begin', 'being', 'binge']
# ['ichnites', 'nitchies']
# ['bearings', 'sabering']
# ['berating', 'rebating', 'tabering']
# ['kolos', 'looks']
# ['ikons', 'kinos', 'oinks']
# ['molders', 'remolds', 'smolder']
# ['stetson', 'testons']
# ['wenchers', 'wrenches']
# ['proette', 'treetop']
# ['rato', 'rota', 'taro', 'tora']
# ['oars', 'osar', 'soar', 'sora']
# ['deking', 'kinged']
# ['duplexes', 'expulsed']
# ['arbutes', 'bursate']
# ['barytes', 'betrays']
# ['cerebrum', 'cumberer']
# ['costumer', 'customer']
# ['knurling', 'runkling']
# ['gnomonic', 'oncoming']
# ['blastier', 'librates']
# ['bima', 'iamb']
# ['camels', 'macles', 'mescal']
# ['alt', 'lat']
# ['isolator', 'ostiolar']
# ['las', 'sal']
# ['sistra', 'sitars', 'stairs']
# ['lusting', 'lutings']
# ['almuce', 'macule']
# ['acnodes', 'deacons']
# ['rillet', 'tiller']
# ['rilles', 'siller']
# ['mutilate', 'ultimate']
# ['sideway', 'wayside']
# ['localites', 'oscillate', 'teocallis']
# ['ablution', 'abutilon']
# ['catties', 'statice']
# ['interims', 'minister', 'misinter']
# ['strewer', 'wrester']
# ['agars', 'ragas']
# ['daggles', 'slagged']
# ['draggle', 'gargled']
# ['innings', 'sinning']
# ['leviable', 'liveable']
# ['lienable', 'lineable']
# ['ancestor', 'enactors']
# ['atoner', 'ornate']
# ['arseno', 'reason', 'senora']
# ['bawlers', 'warbles']
# ['blaster', 'labrets', 'stabler']
# ['grandiose', 'organdies', 'organised']
# ['chintses', 'snitches']
# ['ladyish', 'shadily']
# ['digestor', 'stodgier']
# ['orals', 'solar']
# ['valor', 'volar']
# ['japers', 'jasper']
# ['coarsening', 'ignorances']
# ['declension', 'indolences']
# ['overbusy', 'overbuys']
# ['forests', 'fosters']
# ['mangiest', 'mintages', 'misagent', 'steaming']
# ['hustings', 'unsights']
# ['hoars', 'horas']
# ['durmasts', 'mustards']
# ['defoam', 'foamed']
# ['dioxides', 'oxidised']
# ['buttered', 'rebutted']
# ['busts', 'stubs']
# ['enervates', 'venerates']
# ['gledes', 'gleeds', 'ledges', 'sledge']
# ['encores', 'necrose']
# ['curial', 'uracil']
# ['bribing', 'ribbing']
# ['bazar', 'braza']
# ['coroner', 'crooner']
# ['cutlets', 'cuttles', 'scuttle']
# ['coupons', 'soupcon']
# ['cooker', 'recook']
# ['cilantro', 'contrail']
# ['intort', 'triton']
# ['panels', 'planes']
# ['planet', 'platen']
# ['odyle', 'yodel', 'yodle']
# ['doles', 'lodes', 'soled']
# ['dowel', 'lowed']
# ['loved', 'voled']
# ['activate', 'cavitate']
# ['citruses', 'curtsies', 'rictuses']
# ['catechins', 'chanciest']
# ['haptic', 'phatic']
# ['faller', 'refall']
# ['girds', 'grids']
# ['ainsells', 'sensilla']
# ['bromes', 'ombers', 'ombres', 'somber', 'sombre']
# ['perms', 'sperm']
# ['presetting', 'pretesting']
# ['blessing', 'glibness']
# ['fatso', 'softa']
# ['fossa', 'sofas']
# ['disprove', 'provides']
# ['diopters', 'dioptres', 'peridots', 'proteids', 'riposted']
# ['disposer', 'dropsies']
# ['fastener', 'fenestra', 'refasten']
# ['assumers', 'masseurs']
# ['degrader', 'regarded', 'regraded']
# ['priseres', 'reprises', 'respires']
# ['ashlering', 'narghiles', 'nargilehs']
# ['capotes', 'toecaps']
# ['attainer', 'reattain']
# ['deflower', 'flowered', 'reflowed']
# ['beringed', 'breeding']
# ['fallouts', 'outfalls']
# ['girths', 'griths', 'rights']
# ['planets', 'platens']
# ['cluster', 'cutlers', 'relucts']
# ['chiros', 'choirs', 'ichors', 'orchis']
# ['espouser', 'repousse']
# ['perverse', 'preserve']
# ['cangues', 'uncages']
# ['pulsion', 'upsilon']
# ['aroints', 'rations']
# ['ferry', 'fryer', 'refry']
# ['em', 'me']
# ['conveyer', 'reconvey']
# ['restamp', 'stamper', 'tampers']
# ['er', 're']
# ['strick', 'tricks']
# ['kae', 'kea']
# ['glosser', 'regloss']
# ['glowers', 'reglows']
# ['glovers', 'grovels']
# ['bemired', 'berimed']
# ['moxie', 'oxime']
# ['pylori', 'ropily']
# ['ragtag', 'tagrag']
# ['overtakes', 'takeovers']
# ['overdare', 'overdear']
# ['helotries', 'hoteliers']
# ['bugle', 'bulge']
# ['setous', 'touses']
# ['appends', 'snapped']
# ['snottier', 'tritones']
# ['routines', 'snoutier']
# ['levanter', 'relevant']
# ['sutras', 'tarsus', 'tussar']
# ['anisettes', 'tetanises']
# ['bogle', 'globe']
# ['mislearnt', 'terminals']
# ['onrushes', 'unhorses']
# ['depolish', 'polished']
# ['numberers', 'renumbers']
# ['durst', 'turds']
# ['insoles', 'lesions', 'lioness']
# ['evocator', 'overcoat']
# ['moodiest', 'sodomite']
# ['ervil', 'liver', 'livre', 'viler']
# ['credits', 'directs']
# ['prostyle', 'protyles']
# ['cyder', 'decry']
# ['postured', 'proudest', 'sprouted']
# ['myrtle', 'termly']
# ['hurts', 'ruths']
# ['defacer', 'refaced']
# ['girdled', 'griddle']
# ['altruisms', 'muralists', 'ultraisms']
# ['ostioles', 'stoolies']
# ['septical', 'tieclasp']
# ['slipcase', 'specials']
# ['radices', 'sidecar']
# ['acrider', 'carried']
# ['glomus', 'moguls']
# ['dioxids', 'ixodids']
# ['drafter', 'redraft']
# ['cutesy', 'cuteys']
# ['hosed', 'shoed']
# ['ephod', 'hoped']
# ['haptenes', 'heptanes']
# ['pipets', 'sippet']
# ['daunter', 'natured', 'unrated', 'untread']
# ['bedmaker', 'embarked']
# ['thirsting', 'trithings']
# ['carless', 'classer', 'scalers', 'scleras']
# ['cartels', 'clarets', 'crestal', 'scarlet']
# ['lonesome', 'oenomels']
# ['desanding', 'saddening']
# ['restaff', 'staffer']
# ['zaffers', 'zaffres']
# ['pitiers', 'tipsier']
# ['sutta', 'tauts']
# ['twats', 'watts']
# ['masters', 'streams']
# ['amusers', 'assumer', 'masseur']
# ['arts', 'rats', 'star', 'tars', 'tsar']
# ['coinfers', 'conifers', 'forensic', 'fornices']
# ['balder', 'blared']
# ['layouts', 'outlays']
# ['belady', 'dyable']
# ['albedo', 'doable']
# ['ambled', 'bedlam', 'beldam', 'blamed', 'lambed']
# ['rads', 'sard']
# ['dart', 'drat', 'trad']
# ['draw', 'ward']
# ['dray', 'yard']
# ['druse', 'dures']
# ['chokers', 'hockers', 'shocker']
# ['stipple', 'tipples']
# ['baht', 'bath']
# ['saw', 'was']
# ['schmoose', 'smooches']
# ['sat', 'tas']
# ['ays', 'say']
# ['dagos', 'goads']
# ['diatoms', 'mastoid']
# ['fluids', 'sulfid']
# ['buns', 'nubs', 'snub']
# ['chanson', 'noncash']
# ['micellar', 'millrace']
# ['cacklers', 'clackers', 'crackles']
# ['every', 'veery']
# ['lettering', 'reletting']
# ['begird', 'bridge']
# ['codder', 'corded']
# ['preteens', 'pretense', 'terpenes']
# ['bids', 'dibs']
# ['bird', 'drib']
# ['ligament', 'metaling', 'tegminal']
# ['basins', 'sabins']
# ['claspers', 'reclasps', 'scalpers']
# ['sceptral', 'spectral']
# ['slickest', 'stickles']
# ['pikers', 'spiker']
# ['perhapses', 'preshapes']
# ['entropies', 'interpose']
# ['gaums', 'magus', 'sagum']
# ['aims', 'amis', 'sima']
# ['continuos', 'contusion']
# ['amir', 'mair', 'rami']
# ['imam', 'maim']
# ['palish', 'phials']
# ['arval', 'larva']
# ['leys', 'lyes', 'lyse']
# ['lest', 'lets']
# ['lues', 'slue']
# ['ferrous', 'furores']
# ['enslave', 'leavens']
# ['lateens', 'leanest']
# ['choosers', 'soroches']
# ['ocherous', 'ochreous']
# ['exacter', 'excreta']
# ['rasher', 'sharer']
# ['just', 'juts']
# ['abying', 'baying']
# ['dispel', 'lisped', 'sliped', 'spiled']
# ['chowder', 'cowherd']
# ['agists', 'staigs']
# ['loaners', 'reloans']
# ['bonefish', 'fishbone']
# ['battling', 'blatting']
# ['lopers', 'polers', 'proles', 'sloper', 'splore']
# ['pews', 'spew']
# ['algoid', 'dialog']
# ['spue', 'supe']
# ['kills', 'skill']
# ['demounts', 'mudstone']
# ['oot', 'too']
# ['endosomes', 'moonseeds']
# ['teens', 'tense']
# ['hognut', 'nought']
# ['chopin', 'phonic']
# ['ickers', 'sicker']
# ['parishes', 'sharpies']
# ['moidore', 'moodier']
# ['panel', 'penal', 'plane', 'plena']
# ['notal', 'talon', 'tolan', 'tonal']
# ['loans', 'salon', 'solan']
# ['edile', 'elide']
# ['doer', 'redo', 'rode']
# ['does', 'dose', 'odes']
# ['dote', 'toed']
# ['stickler', 'strickle', 'ticklers', 'trickles']
# ['meloid', 'moiled']
# ['limned', 'milden']
# ['sunset', 'unsets']
# ['misled', 'slimed', 'smiled']
# ['dimple', 'limped']
# ['redated', 'treaded']
# ['argling', 'glaring']
# ['costarred', 'redactors']
# ['argle', 'glare', 'lager', 'large', 'regal']
# ['angel', 'angle', 'glean']
# ['discoverers', 'rediscovers']
# ['holt', 'loth']
# ['licenses', 'silences']
# ['kinfolks', 'kinsfolk']
# ['sparsest', 'trespass']
# ['bongoist', 'boosting']
# ['humorist', 'thoriums']
# ['corders', 'records']
# ['nepotism', 'pimentos']
# ['ben', 'neb']
# ['bey', 'bye']
# ['caliche', 'chalice']
# ['haunter', 'unearth', 'urethan']
# ['poet', 'tope']
# ['pepo', 'pope']
# ['pore', 'rope']
# ['epos', 'opes', 'peso', 'pose']
# ['cernuous', 'coenurus']
# ['caduceus', 'caucused']
# ['cleaners', 'cleanser', 'recleans']
# ['deserts', 'dessert', 'tressed']
# ['eglateres', 'regelates', 'relegates']
# ['dodging', 'godding']
# ['dup', 'pud']
# ['areic', 'ceria', 'erica']
# ...
# ['gallnuts', 'nutgalls']
# ['hayed', 'heady']
# ['death', 'hated']
# ['ashed', 'deash', 'hades', 'heads', 'sadhe', 'shade']
# ['hared', 'heard']
# ['chlorites', 'clothiers']
# ['spitter', 'tipster']
# ['endosome', 'moonseed']
# ['coiffes', 'offices']
# ['duels', 'dulse', 'leuds', 'slued']
# ['clupeoid', 'upcoiled']
# ['drabbest', 'drabbets']
# ['frumenty', 'furmenty']
# ['dingo', 'doing']
# ['atopies', 'opiates']
# ['arrest', 'rarest', 'raster', 'raters', 'starer', 'tarres', 'terras']
# ['abators', 'rabatos']
# ['thyroids', 'thyrsoid']
# ['amitrole', 'rolamite']
# ['purposes', 'supposer']
# ['absorption', 'probations']
# ['disks', 'skids']
# ['espials', 'lapises', 'lipases', 'palsies']
# ['askant', 'tankas']
# ['acrid', 'caird', 'daric']
# ['acids', 'asdic', 'cadis', 'caids']
# ['eternized', 'tenderize']
# ['azo', 'zoa']
# ['tumbler', 'tumbrel']
# ['netter', 'tenter']
# ['neuter', 'retune', 'tenure', 'tureen']
# ['amercers', 'creamers', 'screamer']
# ['ghouls', 'loughs', 'slough']
# ['overlies', 'relievos', 'voleries']
# ['indenters', 'intenders']
# ['reested', 'steered']
# ['resewed', 'weeders']
# ['deserve', 'severed']
# ['reseeds', 'seeders']
# ['carps', 'craps', 'scarp', 'scrap']
# ['lowdowns', 'slowdown']
# ['retint', 'tinter']
# ['triune', 'uniter']
# ['twiner', 'winter']
# ['citolas', 'stoical']
# ['dingeys', 'dyeings']
# ['elhi', 'heil']
# ['fairs', 'fiars']
# ['conspired', 'incorpsed']
# ['ossuary', 'suasory']
# ['bandies', 'basined']
# ['snooping', 'spooning']
# ['deperms', 'premeds']
# ['gentries', 'integers', 'reesting', 'steering']
# ['outspend', 'unposted']
# ['limas', 'mails', 'salmi']
# ['rethinks', 'thinkers']
# ['openest', 'pentose', 'posteen', 'poteens']
# ['idioms', 'iodism']
# ['chained', 'echidna']
# ['achenes', 'enchase']
# ['lowers', 'rowels', 'slower']
# ['lovers', 'solver']
# ['ostler', 'sterol']
# ['lessor', 'losers', 'sorels']
# ['dinettes', 'insetted']
# ['hormones', 'moorhens']
# ['beater', 'berate', 'rebate']
# ['avower', 'reavow']
# ['dissenter', 'residents']
# ['attestor', 'testator']
# ['dagoes', 'dosage', 'seadog']
# ['dotage', 'togaed']
# ['chute', 'teuch']
# ['amenders', 'meanders']
# ['opposer', 'propose']
# ['prescores', 'reprocess']
# ['cist', 'tics']
# ['clambers', 'scramble']
# ['awning', 'waning']
# ['bike', 'kibe']
# ['gangers', 'granges', 'naggers']
# ['bier', 'brie']
# ['isomer', 'moires', 'rimose']
# ['inkle', 'liken']
# ['cerebrums', 'cumberers']
# ['crushing', 'ruchings']
# ['halloed', 'hollaed']
# ['monology', 'nomology']
# ['oystered', 'storeyed']
# ['fronter', 'refront']
# ['dairies', 'diaries']
# ['amirs', 'mairs', 'simar']
# ['lintier', 'nitrile']
# ['charming', 'marching']
# ['mirza', 'ziram']
# ['pecks', 'speck']
# ['armer', 'rearm']
# ['mares', 'marse', 'maser', 'reams', 'smear']
# ['armet', 'mater', 'ramet', 'tamer']
# ['achromat', 'trachoma']
# ['armpits', 'imparts', 'mispart']
# ['bloats', 'oblast']
# ['colorism', 'miscolor']
# ['ascribed', 'carbides']
# ['garret', 'garter', 'grater']
# ['copula', 'cupola']
# ['coleus', 'oscule']
# ['argals', 'graals']
# ['fringiest', 'resifting']
# ['enervations', 'venerations']
# ['aptnesses', 'patnesses']
# ['abut', 'tabu', 'tuba']
# ['armonicas', 'macaronis']
# ['generate', 'teenager']
# ['boarded', 'roadbed']
# ['corseted', 'escorted', 'sectored']
# ['kinder', 'kirned']
# ['nobs', 'snob']
# ['employers', 'reemploys']
# ['mot', 'tom']
# ['creators', 'reactors']
# ['pavins', 'spavin']
# ['paints', 'patins', 'pintas', 'ptisan']
# ['pissant', 'ptisans']
# ['archaism', 'charisma']
# ['cuffs', 'scuff']
# ['posting', 'stoping']
# ['ekistic', 'ickiest']
# ['lapses', 'passel', 'saleps', 'sepals', 'spales']
# ['palest', 'palets', 'pastel', 'petals', 'plates', 'pleats', 'septal', 'staple']
# ['holsters', 'hostlers']
# ['priested', 'respited']
# ['coarsens', 'narcoses']
# ['motioner', 'remotion']
# ['ionomers', 'moonrise']
# ['factures', 'furcates']
# ['sedating', 'steading']
# ['backmost', 'tombacks']
# ['adverb', 'braved']
# ['statute', 'tautest']
# ['selsyns', 'slyness']
# ['tuners', 'unrest']
# ['enclave', 'valence']
# ['cleanse', 'enlaces', 'scalene']
# ['cleaner', 'reclean']
# ['avowers', 'oversaw', 'reavows']
# ['immersed', 'simmered']
# ['esteem', 'mestee']
# ['epical', 'plaice', 'plicae']
# ['eclair', 'lacier']
# ['stroller', 'trollers']
# ['bag', 'gab']
# ['alb', 'bal', 'lab']
# ['ban', 'nab']
# ['abo', 'boa']
# ['bar', 'bra']
# ['aby', 'bay']
# ['litharge', 'thirlage']
# ['fulmined', 'unfilmed']
# ['gelations', 'legations']
# ['nestor', 'noters', 'stoner', 'tenors', 'tensor', 'toners', 'trones']
# ['pulings', 'pulsing']
# ['algor', 'argol', 'goral', 'largo']
# ['gaols', 'goals']
# ['bagnios', 'gabions']
# ['coots', 'scoot']
# ['divers', 'drives']
# ['gongs', 'noggs']
# ['pittings', 'spitting']
# ['lagered', 'regaled']
# ['asperated', 'separated']
# ['learner', 'relearn']
# ['unpaired', 'unrepaid']
# ['markers', 'remarks']
# ['alkalies', 'alkalise']
# ['intensest', 'sentients']
# ['lumpen', 'plenum']
# ['uveal', 'value']
# ['greened', 'reneged']
# ['presented', 'repetends']
# ['seeks', 'skees']
# ['keets', 'skeet', 'steek']
# ['gerents', 'regents']
# ['masseters', 'seamsters']
# ['negaton', 'tonnage']
# ['granter', 'regrant']
# ['otto', 'toot']
# ['garners', 'rangers']
# ['outraged', 'ragouted']
# ['lucks', 'sculk']
# ['emission', 'simonies']
# ['lucres', 'ulcers']
# ['neither', 'therein']
# ['eftsoon', 'festoon']
# ['wye', 'yew']
# ['humidors', 'rhodiums']
# ['dustpans', 'upstands']
# ['limestone', 'milestone']
# ['sunward', 'undraws']
# ['heptagon', 'pathogen']
# ['slavey', 'sylvae']
# ['bin', 'nib']
# ['bio', 'obi']
# ['bis', 'sib']
# ['rickets', 'sticker', 'tickers']
# ['kayos', 'okays']
# ['acreages', 'gearcase']
# ['timbers', 'timbres']
# ['fugling', 'gulfing']
# ['cuts', 'scut']
# ['linsey', 'lysine']
# ['retorts', 'rotters', 'stertor']
# ['rouster', 'routers', 'tourers', 'trouser']
# ['listers', 'relists']
# ['silvers', 'slivers']
# ['levins', 'livens', 'snivel']
# ['leasing', 'linages', 'sealing']
# ['leaping', 'pealing']
# ['leaving', 'vealing']
# ['linguae', 'unagile']
# ['atingle', 'elating', 'gelatin', 'genital']
# ['peeries', 'seepier']
# ['staunched', 'unscathed']
# ['skips', 'spiks']
# ['thrawing', 'wrathing']
# ['wiggler', 'wriggle']
# ['funfair', 'ruffian']
# ['valencia', 'valiance']
# ['analcite', 'laitance']
# ['bearding', 'breading']
# ['beadings', 'debasing']
# ['unenvied', 'unveined']
# ['impresses', 'premisses']
# ['conker', 'reckon']
# ['comets', 'comtes']
# ['infidel', 'infield']
# ['northing', 'thorning', 'throning']
# ['corer', 'crore']
# ['entirely', 'lientery']
# ['swipe', 'wipes']
# ['hoarsen', 'senhora']
# ['situses', 'tissues']
# ['leister', 'sterile']
# ['swith', 'whist', 'whits']
# ['disport', 'torpids']
# ['ambry', 'barmy']
# ['rumba', 'umbra']
# ['suit', 'tuis']
# ['portly', 'protyl']
# ['machismos', 'masochism']
# ['mucor', 'mucro']
# ['cornice', 'crocein', 'crocine']
# ['deforces', 'frescoed']
# ['lapin', 'plain']
# ['angers', 'ranges', 'sanger']
# ['breakouts', 'outbreaks']
# ['pingrasses', 'preassigns']
# ['arvos', 'savor']
# ['ratos', 'roast', 'rotas', 'taros', 'toras']
# ['soars', 'soras']
# ['chaste', 'cheats', 'sachet', 'scathe', 'taches']
# ['nuptial', 'unplait']
# ['inaptly', 'ptyalin']
# ['finder', 'friend', 'redfin', 'refind']
# ['pedicel', 'pedicle']
# ['assisted', 'disseats']
# ['orc', 'roc']
# ['denticles', 'stenciled']
# ['enlistee', 'selenite']
# ['kitsch', 'shtick', 'thicks']
# ['heils', 'shiel']
# ['bellowed', 'bowelled']
# ['acrasin', 'arnicas', 'carinas']
# ['hassock', 'shackos']
# ['ordainers', 'reordains']
# ['pursuing', 'usurping']
# ['equators', 'quaestor']
# ['hows', 'show']
# ['host', 'hots', 'shot', 'soth', 'tosh']
# ['outworks', 'workouts']
# ['cusks', 'sucks']
# ['cestus', 'scutes']
# ['bonitoes', 'eobionts']
# ['elapses', 'pleases']
# ['dons', 'nods']
# ['acorn', 'narco', 'racon']
# ['canto', 'cotan']
# ['apiary', 'piraya']
# ['censes', 'scenes']
# ['caponiers', 'procaines']
# ['gargles', 'laggers', 'raggles']
# ['palters', 'persalt', 'plaster', 'platers', 'psalter', 'stapler']
# ['perusal', 'pleuras']
# ['parleys', 'parsley', 'players', 'replays', 'sparely']
# ['goglet', 'toggle']
# ['flesh', 'shelf']
# ['migrants', 'smarting']
# ['pelter', 'petrel']
# ['lepers', 'repels']
# ['peelings', 'sleeping', 'speeling']
# ['coiffeurs', 'coiffures']
# ['gursh', 'shrug']
# ['earplug', 'graupel', 'plaguer']
# ['rapparees', 'reappears']
# ['pastural', 'spatular']
# ['scourges', 'scrouges']
# ['legist', 'legits']
# ['airless', 'resails', 'sailers', 'serails', 'serials']
# ['caimans', 'maniacs']
# ['caveats', 'vacates']
# ['reversals', 'slaverers']
# ['retrench', 'trencher']
# ['aileron', 'alienor']
# ['inuring', 'ruining']
# ['elation', 'toenail']
# ['outweary', 'routeway']
# ['papers', 'sapper']
# ['papery', 'prepay', 'yapper']
# ['bagnio', 'gabion']
# ['atrocity', 'citatory']
# ['bootjack', 'jackboot']
# ['formulae', 'fumarole']
# ['amnions', 'mansion', 'onanism']
# ['vanishers', 'varnishes']
# ['glede', 'gleed', 'ledge']
# ['rowdier', 'wordier', 'worried']
# ['economies', 'monoecies']
# ['citral', 'rictal']
# ['attuned', 'nutated', 'taunted']
# ['swelters', 'wrestles']
# ['adjusters', 'readjusts']
# ['immersing', 'simmering']
# ['jitters', 'trijets']
# ['incests', 'insects']
# ['logs', 'slog']
# ['gelding', 'niggled']
# ['hassling', 'lashings', 'slashing']
# ['shawling', 'whalings']
# ['atticists', 'statistic']
# ['seiners', 'sereins', 'serines']
# ['entires', 'entries', 'trienes']
# ['newsier', 'weiners', 'wieners']
# ['enviers', 'inverse', 'veiners', 'venires', 'versine']
# ['agaves', 'savage']
# ['insigne', 'seining']
# ['ginnier', 'reining']
# ['grey', 'gyre']
# ['beamy', 'embay', 'maybe']
# ['outslept', 'outspelt']
# ['perfect', 'prefect']
# ['dalesmen', 'leadsmen']
# ['infarcts', 'infracts']
# ['enlister', 'listener', 'reenlist', 'silenter']
# ['acetose', 'coatees']
# ['esthete', 'teethes']
# ['armpit', 'impart']
# ['stinting', 'tintings']
# ['epeeists', 'seepiest']
# ['probationers', 'reprobations']
# ['miseats', 'misseat', 'samites', 'tamises']
# ['massive', 'mavises']
# ['maltster', 'martlets']
# ['livest', 'vilest']
# ['battler', 'blatter', 'brattle']
# ['mozos', 'zooms']
# ['setae', 'tease']
# ['nestles', 'netless']
# ['inertias', 'rainiest']
# ['ovals', 'salvo']
# ['tribunals', 'turbinals']
# ['sorbets', 'strobes']
# ['heughs', 'sheugh']
# ['oaths', 'shoat']
# ['gust', 'guts', 'tugs']
# ['overstir', 'servitor']
# ['dent', 'tend']
# ['olives', 'voiles']
# ['nonesuch', 'unchosen']
# ['lepidote', 'petioled']
# ['magisters', 'sterigmas']
# ['agnomen', 'nongame']
# ['amortizes', 'atomizers']
# ['washier', 'wearish']
# ['gemmates', 'tagmemes']
# ['heelposts', 'pestholes']
# ['burbly', 'rubbly']
# ['joiner', 'rejoin']
# ['beers', 'brees']
# ['ioniums', 'nimious']
# ['aldoses', 'lassoed']
# ['ernes', 'sneer']
# ['newer', 'renew']
# ['nerve', 'never']
# ['hantle', 'thenal']
# ['loden', 'olden']
# ['drawing', 'warding']
# ['unlevied', 'unveiled']
# ['centrist', 'citterns']
# ['draying', 'yarding']
# ['flames', 'fleams']
# ['stiff', 'tiffs']
# ['truest', 'utters']
# ['primroses', 'promisers']
# ['axites', 'taxies']
# ['deave', 'eaved', 'evade']
# ['crumpets', 'spectrum']
# ['adeem', 'edema']
# ['distincter', 'interdicts']
# ['antherids', 'tarnished']
# ['inert', 'inter', 'niter', 'nitre', 'trine']
# ['reins', 'resin', 'rinse', 'risen', 'serin', 'siren']
# ['decider', 'decried']
# ['alchemic', 'chemical']
# ['caliches', 'chalices']
# ['digesters', 'redigests']
# ['pectates', 'spectate']
# ['ungual', 'ungula']
# ['setup', 'stupe', 'upset']
# ['charpais', 'haircaps']
# ['installed', 'landsleit']
# ['desugar', 'sugared']
# ['motet', 'motte', 'totem']
# ['lewder', 'reweld', 'welder']
# ['dueler', 'eluder']
# ['ajar', 'raja']
# ['pickets', 'skeptic']
# ['innovates', 'venations']
# ['biocidal', 'diabolic']
# ['miens', 'mines']
# ['damneder', 'demander', 'redemand', 'remanded']
# ['midspaces', 'misspaced']
# ['encashed', 'enchased']
# ['pilous', 'poilus']
# ['pilots', 'pistol', 'spoilt']
# ['pawns', 'spawn']
# ['snaps', 'spans']
# ['altercations', 'intercoastal']
# ['farting', 'ingraft', 'rafting']
# ['eternals', 'telerans']
# ['athirst', 'rattish', 'tartish']
# ['cattiness', 'scantiest', 'tacitness']
# ['chivy', 'vichy']
# ['demotics', 'domestic']
# ['kytes', 'tykes']
# ['gunship', 'pushing']
# ['definer', 'refined']
# ['reserver', 'reverers', 'reverser']
# ['brutes', 'burets', 'buster', 'rebuts', 'tubers']
# ['ihrams', 'marish']
# ['thairm', 'thiram']
# ['fist', 'fits', 'sift']
# ['periled', 'replied']
# ['speiled', 'spieled']
# ['generating', 'greatening']
# ['insister', 'sinister']
# ['assent', 'sanest', 'stanes']
# ['deports', 'redtops', 'sported']
# ['ringtaws', 'strawing']
# ['stingray', 'straying']
# ['curdier', 'curried']
# ['alexin', 'xenial']
# ['entail', 'tenail', 'tineal']
# ['alevin', 'alvine', 'valine', 'veinal', 'venial', 'vineal']
# ['alpine', 'penial', 'pineal']
# ['aliner', 'larine', 'linear', 'nailer']
# ['aloft', 'float', 'flota']
# ['foals', 'loafs']
# ['lumber', 'rumble']
# ['aloof', 'loofa']
# ['piercers', 'preciser', 'reprices']
# ['devote', 'vetoed']
# ['intorts', 'tritons']
# ['doom', 'mood']
# ['carom', 'macro']
# ['ariette', 'iterate']
# ['phaseout', 'taphouse']
# ['peckier', 'pickeer']
# ['brute', 'buret', 'rebut', 'tuber']
# ['nattiness', 'stannites']
# ['norite', 'orient', 'tonier']
# ['fines', 'neifs']
# ['finer', 'infer']
# ['aspirants', 'partisans']
# ['discerns', 'rescinds']
# ['gestapos', 'postages']
# ['innerves', 'nervines']
# ['intenser', 'internes']
# ['horseless', 'shoreless']
# ['flenser', 'fresnel']
# ['basion', 'bonsai']
# ['outrides', 'outsider']
# ['rowdiest', 'wordiest']
# ['bonita', 'obtain']
# ['notables', 'stonable']
# ['elks', 'leks']
# ['shotting', 'tonights']
# ['shouting', 'southing']
# ['unmerited', 'unmitered']
# ['psalming', 'sampling']
# ['incorporate', 'procreation']
# ['overhates', 'overheats']
# ['lenses', 'lessen']
# ['pothers', 'strophe', 'thorpes']
# ['impressive', 'permissive']
# ['alcove', 'coeval']
# ['ars', 'ras']
# ['art', 'rat', 'tar']
# ['coaler', 'oracle', 'recoal']
# ['raw', 'war']
# ['ray', 'rya', 'yar']
# ['crispen', 'pincers', 'princes']
# ['lassoer', 'oarless', 'serosal']
# ['badmen', 'bedamn']
# ['hurtles', 'hustler']
# ['abos', 'boas']
# ['cupfuls', 'cupsful']
# ['ensorceled', 'redolences']
# ['noosers', 'sooners']
# ['marascas', 'mascaras']
# ['kue', 'uke']
# ['carp', 'crap']
# ['conspire', 'incorpse']
# ['asserting', 'astringes', 'ganisters']
# ['rykes', 'yerks']
# ['entoderms', 'modernest']
# ['oneriest', 'serotine']
# ['flue', 'fuel']
# ['felt', 'left']
# ['scrieving', 'servicing']
# ['anon', 'nona']
# ['dignity', 'tidying']
# ['ceriphs', 'ciphers', 'spheric']
# ['most', 'mots', 'toms']
# ['matless', 'samlets']
# ['lyre', 'rely']
# ['casually', 'causally']
# ['dewans', 'snawed']
# ['breadnut', 'turbaned']
# ['bury', 'ruby']
# ['balancer', 'barnacle']
# ['overhate', 'overheat']
# ['propenes', 'propense']
# ['clasps', 'scalps']
# ['epidotes', 'poetised']
# ['pastiches', 'pistaches']
# ['paik', 'pika']
# ['ardebs', 'bardes', 'beards', 'breads', 'debars', 'sabred', 'serdab']
# ['ilka', 'kail']
# ['brayed', 'redbay']
# ['bedewing', 'bewinged']
# ['egoists', 'stogies']
# ['cesium', 'miscue']
# ['cementers', 'cerements']
# ['cabestro', 'cabresto']
# ['enteral', 'eternal', 'teleran']
# ['calls', 'scall']
# ['rashes', 'shares', 'shears']
# ['hawser', 'rewash', 'washer']
# ['havers', 'shaver']
# ['earths', 'haters', 'hearts']
# ['keeping', 'peeking']
# ['seeking', 'skeeing']
# ['keening', 'kneeing']
# ['salved', 'slaved']
# ['ghis', 'sigh']
# ['teeter', 'terete']
# ['enlist', 'inlets', 'listen', 'silent', 'tinsel']
# ['allonge', 'galleon']
# ['fetors', 'forest', 'fortes', 'foster', 'softer']
# ['beeches', 'beseech']
# ['bakers', 'brakes', 'breaks', 'kebars']
# ['astuteness', 'tautnesses']
# ['synergid', 'syringed']
# ['realist', 'retails', 'saltier', 'saltire', 'slatier', 'tailers']
# ['couplet', 'octuple']
# ['arias', 'raias']
# ['atria', 'riata', 'tiara']
# ['lakers', 'slaker']
# ['denes', 'dense', 'needs']
# ['deny', 'dyne']
# ['vavasors', 'vavassor']
# ['dens', 'ends', 'send', 'sned']
# ['dune', 'nude', 'unde']
# ['done', 'node']
# ['detick', 'ticked']
# ['dicker', 'ricked']
# ['darting', 'trading']
# ['darings', 'gradins']
# ['beslime', 'besmile']
# ['unreadiest', 'unsteadier']
# ['reinstated', 'straitened']
# ['krait', 'traik']
# ['heptads', 'spathed']
# ['bagasse', 'seabags']
# ['enclaves', 'valences']
# ['sunroof', 'unroofs']
# ['chape', 'cheap', 'peach']
# ['chare', 'reach']
# ['aches', 'chase']
# ['cheat', 'tache', 'teach', 'theca']
# ['must', 'muts', 'smut', 'stum']
# ['chela', 'leach']
# ['incest', 'insect', 'nicest']
# ['theist', 'tithes']
# ['earstones', 'resonates']
# ['draper', 'parred']
# ['drapes', 'padres', 'parsed', 'rasped', 'spader', 'spared', 'spread']
# ['grunted', 'trudgen']
# ['glowered', 'reglowed']
# ['mutual', 'umlaut']
# ['enter', 'rente', 'terne']
# ['beraking', 'breaking']
# ['revamps', 'vampers']
# ['cheaper', 'peacher']
# ['pisses', 'sepsis', 'speiss']
# ['boyards', 'byroads']
# ['rident', 'tinder', 'trined']
# ['menses', 'semens']

# %% [markdown]
# 2\. Modify the previous program so that it prints the largest set of anagrams first, followed by the second largest set, and so on.

# %%
def print_anagrams(file_name):
    words = []
    # Reads word list from a file:
    fin = open(file_name)
    for line in fin:
        word = line.strip()
        words.append(word)
    # make dictionary
    words_dict = dict()
    for word in words:
        # make sorted word a key and add the word
        key = ''.join(sorted(word))
        if key in words_dict:
            words_dict[key].append(word)
        else:
            words_dict[key] = [word]
    anagrams = []
    i = 0
    for k in words_dict:
        if len(words_dict[k])>1:
            anagrams.append(words_dict[k])
    print sort_by_length(anagrams)
    
print_anagrams('words.txt')
# Out:
# [['apers', 'asper', 'pares', 'parse', 'pears', 'prase', 'presa', 'rapes', 'reaps', 'spare', 'spear'], ['alerts', 'alters', 'artels', 'estral', 'laster', 'ratels', 'salter', 'slater', 'staler', 'stelar', 'talers'], ['least', 'setal', 'slate', 'stale', 'steal', 'stela', 'taels', 'tales', 'teals', 'tesla'], ['estrin', 'inerts', 'insert', 'inters', 'niters', 'nitres', 'sinter', 'triens', 'trines'], ['capers', 'crapes', 'escarp', 'pacers', 'parsec', 'recaps', 'scrape', 'secpar', 'spacer'], ['peris', 'piers', 'pries', 'prise', 'ripes', 'speir', 'spier', 'spire'], ['carets', 'cartes', 'caster', 'caters', 'crates', 'reacts', 'recast', 'traces'], ['palest', 'palets', 'pastel', 'petals', 'plates', 'pleats', 'septal', 'staple'], ['anestri', 'nastier', 'ratines', 'retains', 'retinas', 'retsina', 'stainer', 'stearin'], ['earings', 'erasing', 'gainers', 'reagins', 'regains', 'reginas', 'searing', 'seringa'], ['aspers', 'parses', 'passer', 'prases', 'repass', 'spares', 'sparse', 'spears'], ['acers', 'acres', 'cares', 'carse', 'escar', 'races', 'scare', 'serac'], ['ates', 'east', 'eats', 'etas', 'sate', 'seat', 'seta', 'teas'], ['lapse', 'leaps', 'pales', 'peals', 'pleas', 'salep', 'sepal', 'spale'], ['arles', 'earls', 'lares', 'laser', 'lears', 'rales', 'reals', 'seral'], ['paste', 'pates', 'peats', 'septa', 'spate', 'tapes', 'tepas'], ['ardebs', 'bardes', 'beards', 'breads', 'debars', 'sabred', 'serdab'], ['estrous', 'oestrus', 'ousters', 'sourest', 'souters', 'stoures', 'tussore'], ['armets', 'master', 'maters', 'matres', 'ramets', 'stream', 'tamers'], ['artiest', 'artiste', 'attires', 'iratest', 'ratites', 'striate', 'tastier'], ['enosis', 'eosins', 'essoin', 'noesis', 'noises', 'ossein', 'sonsie'], ['aspen', 'napes', 'neaps', 'panes', 'peans', 'sneap', 'spean'], ['emits', 'items', 'metis', 'mites', 'smite', 'stime', 'times'], ['ariled', 'derail', 'dialer', 'laired', 'railed', 'redial', 'relaid'], ['drapes', 'padres', 'parsed', 'rasped', 'spader', 'spared', 'spread'], ['caret', 'carte', 'cater', 'crate', 'react', 'recta', 'trace'], ['algins', 'aligns', 'lasing', 'liangs', 'ligans', 'lingas', 'signal'], ['amens', 'manes', 'manse', 'means', 'mensa', 'names', 'nemas'], ['arrest', 'rarest', 'raster', 'raters', 'starer', 'tarres', 'terras'], ['abets', 'baste', 'bates', 'beast', 'beats', 'betas', 'tabes'], ['deist', 'diets', 'dites', 'edits', 'sited', 'stied', 'tides'], ['ester', 'reest', 'reset', 'steer', 'stere', 'terse', 'trees'], ['aridest', 'astride', 'diaster', 'disrate', 'staider', 'tardies', 'tirades'], ['resaw', 'sawer', 'sewar', 'sware', 'swear', 'wares', 'wears'], ['ares', 'arse', 'ears', 'eras', 'rase', 'sear', 'sera'], ['peers', 'peres', 'perse', 'prees', 'prese', 'speer', 'spree'], ['merits', 'mister', 'miters', 'mitres', 'remits', 'smiter', 'timers'], ['angriest', 'astringe', 'ganister', 'gantries', 'granites', 'ingrates', 'rangiest'], ['nestor', 'noters', 'stoner', 'tenors', 'tensor', 'toners', 'trones'], ['esprits', 'persist', 'priests', 'spriest', 'sprites', 'stirpes', 'stripes'], ['cruets', 'cruset', 'curets', 'eructs', 'rectus', 'recuts', 'truces'], ['empires', 'emprise', 'epimers', 'imprese', 'premies', 'premise', 'spireme'], ['lavers', 'ravels', 'salver', 'serval', 'slaver', 'velars', 'versal'], ['bares', 'baser', 'bears', 'braes', 'saber', 'sabre'], ['alerting', 'altering', 'integral', 'relating', 'tanglier', 'triangle'], ['alert', 'alter', 'artel', 'later', 'ratel', 'taler'], ['deils', 'delis', 'idles', 'isled', 'sidle', 'slide'], ['aretes', 'easter', 'eaters', 'reseat', 'seater', 'teaser'], ['enters', 'nester', 'rentes', 'resent', 'tenser', 'ternes'], ['airts', 'astir', 'sitar', 'stair', 'stria', 'tarsi'], ['canters', 'nectars', 'recants', 'scanter', 'tanrecs', 'trances'], ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled'], ['mates', 'meats', 'satem', 'steam', 'tames', 'teams'], ['esters', 'reests', 'resets', 'serest', 'steers', 'steres'], ['hales', 'heals', 'leash', 'selah', 'shale', 'sheal'], ['canter', 'cen ...

# %% [markdown]
# 3\. In Scrabble a “bingo” is when you play all seven tiles in your rack, along with a letter on the board, to form an eight-letter word. What set of 8 letters forms the most possible bingos? Hint: there are seven.

# %% [markdown]
# # Quick poll
# About how long did you spend working on this Reading Journal?

# %%
# about 2 hours
